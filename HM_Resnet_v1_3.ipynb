# %% [markdown]
# <a href="https://colab.research.google.com/github/vachaconcu/Mineriadatos/blob/master/HM_Resnet_v1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from os import remove
from skimage.color import rgb2gray
from numpy import load
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from sklearn.model_selection import train_test_split
from google.colab import files
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape,ZeroPadding2D,Activation,MaxPooling2D,Dropout
from keras.layers import BatchNormalization
from keras.models import Model
from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SpatialDropout2D
from matplotlib import pyplot as plt
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D
from tensorflow.keras.layers import MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
from numpy import load
import os
os.chdir('/content/drive/My Drive/Mineria/Train-Test 90%')

datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_HM_train.npz') ; x_train = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_HM_train.npz') ; y_train = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_HM_val_int.npz') ; y_test = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_HM_val_int.npz') ; x_test = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_HM_val_ext.npz') ; y_test2 = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_HM_val_ext.npz') ; x_test2 = datos['arr_0']

# %%
print('x_test =',x_test.shape)
print('x_train =',x_train.shape)
print('y_test =',y_test.shape)
print('y_train =',y_train.shape)
print('x_test =',x_test2.shape)
print('x_train =',y_test2.shape)
# Out:
# x_test = (1719, 200, 200, 3)
# x_train = (6874, 200, 200, 3)
# y_test = (1719, 2)
# y_train = (6874, 2)
# x_test = (2063, 200, 200, 3)
# x_train = (2063, 2)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os

# %%
batch_size = 32 # orig paper trained all networks with batch_size=128
epochs = 200
#epochs = 10
data_augmentation = True
num_classes = 2
# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter para sexo c: 
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 1

# computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
model_type
# Out:
# 'ResNet20v1'

# %%
# input image dimensions.
input_shape = x_train.shape[1:]

#x_train = x_train.astype('float32') 
#x_test = x_test.astype('float32') 

# if subtract pixel mean is enabled 
# center the column-data around zero
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (6874, 200, 200, 3)
# 6874 train samples
# 1719 test samples
# y_train shape: (6874, 2)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=2):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)
    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out
# add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v1(input_shape, depth, num_classes=2):
    """ResNet Version 1 Model builder 

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved
    (downsampled) by a convolutional layer with strides=2, while 
    the number of filters is doubled. Within each stage, 
    the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx 
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32)')
    # start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)
    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:
                # linear projection residual shortcut
                # connection to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 200, 200, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 200, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 200, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 200, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 200, 200, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 200, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 200, 16) 0           activation[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200, 200, 16) 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 200, 200, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 200, 200, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200, 200, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 200, 200, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 200, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200, 200, 16) 0           activation_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200, 200, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 200, 200, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 200, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200, 200, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 200, 200, 16) 2320        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 200, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 200, 200, 16) 0           activation_4[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200, 200, 16) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 100, 100, 32) 4640        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 100, 100, 32) 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100, 100, 32) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 100, 100, 32) 9248        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 100, 100, 32) 544         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 100, 32) 128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 100, 32) 0           conv2d_9[0][0]
#                                                                  batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100, 100, 32) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 100, 100, 32) 9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 100, 100, 32) 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100, 100, 32) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 100, 100, 32) 9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 100, 100, 32) 128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 100, 100, 32) 0           activation_8[0][0]
#                                                                  batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100, 100, 32) 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 100, 32) 9248        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 100, 100, 32) 128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100, 100, 32) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 100, 100, 32) 9248        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 100, 100, 32) 128         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 100, 100, 32) 0           activation_10[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100, 100, 32) 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 50, 50, 64)   18496       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 50, 50, 64)   2112        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 50, 50, 64)   0           conv2d_16[0][0]
#                                                                  batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 50, 50, 64)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 50, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 64)   36928       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 50, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 50, 50, 64)   0           activation_14[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 50, 50, 64)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 50, 50, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 64)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 50, 50, 64)   0           activation_16[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 50, 50, 64)   0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 6, 6, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2304)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            4610        flatten[0][0]
# ==================================================================================================
# Total params: 278,402
# Trainable params: 277,026
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), './Modelos')
model_name = 'HM_n3_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # fit the model on the batches generated by datagen.flow().
    history= model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, 
                        steps_per_epoch=len(x_train)//batch_size,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/200
# 214/214 [==============================] - ETA: 0s - loss: 0.8126 - accuracy: 0.7184
# Epoch 00001: val_accuracy improved from -inf to 0.73182, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.001.h5
# 214/214 [==============================] - 80s 375ms/step - loss: 0.8126 - accuracy: 0.7184 - val_loss: 0.7669 - val_accuracy: 0.7318 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/200
# 214/214 [==============================] - ETA: 0s - loss: 0.6458 - accuracy: 0.7713
# Epoch 00002: val_accuracy improved from 0.73182 to 0.82024, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.002.h5
# 214/214 [==============================] - 81s 378ms/step - loss: 0.6458 - accuracy: 0.7713 - val_loss: 0.5606 - val_accuracy: 0.8202 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/200
# 214/214 [==============================] - ETA: 0s - loss: 0.6002 - accuracy: 0.7930
# Epoch 00003: val_accuracy did not improve from 0.82024
# 214/214 [==============================] - 80s 373ms/step - loss: 0.6002 - accuracy: 0.7930 - val_loss: 0.5922 - val_accuracy: 0.7970 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/200
# 214/214 [==============================] - ETA: 0s - loss: 0.5545 - accuracy: 0.8125
# Epoch 00004: val_accuracy improved from 0.82024 to 0.83886, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.004.h5
# 214/214 [==============================] - 80s 374ms/step - loss: 0.5545 - accuracy: 0.8125 - val_loss: 0.5193 - val_accuracy: 0.8389 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/200
# 214/214 [==============================] - ETA: 0s - loss: 0.5307 - accuracy: 0.8310
# Epoch 00005: val_accuracy did not improve from 0.83886
# 214/214 [==============================] - 79s 371ms/step - loss: 0.5307 - accuracy: 0.8310 - val_loss: 0.5479 - val_accuracy: 0.8034 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/200
# 214/214 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8486
# Epoch 00006: val_accuracy did not improve from 0.83886
# 214/214 [==============================] - 81s 378ms/step - loss: 0.4931 - accuracy: 0.8486 - val_loss: 0.5757 - val_accuracy: 0.8173 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/200
# 214/214 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.8565
# Epoch 00007: val_accuracy improved from 0.83886 to 0.86853, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.007.h5
# 214/214 [==============================] - 81s 378ms/step - loss: 0.4663 - accuracy: 0.8565 - val_loss: 0.4476 - val_accuracy: 0.8685 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/200
# 214/214 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.8696
# Epoch 00008: val_accuracy improved from 0.86853 to 0.89122, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.008.h5
# 214/214 [==============================] - 80s 376ms/step - loss: 0.4412 - accuracy: 0.8696 - val_loss: 0.4012 - val_accuracy: 0.8912 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/200
# 214/214 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8790
# Epoch 00009: val_accuracy did not improve from 0.89122
# 214/214 [==============================] - 79s 371ms/step - loss: 0.4215 - accuracy: 0.8790 - val_loss: 0.5273 - val_accuracy: 0.8581 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8932
# Epoch 00010: val_accuracy did not improve from 0.89122
# 214/214 [==============================] - 79s 371ms/step - loss: 0.3907 - accuracy: 0.8932 - val_loss: 0.4039 - val_accuracy: 0.8802 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8933
# Epoch 00011: val_accuracy improved from 0.89122 to 0.90111, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.011.h5
# 214/214 [==============================] - 80s 373ms/step - loss: 0.3814 - accuracy: 0.8933 - val_loss: 0.3723 - val_accuracy: 0.9011 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3770 - accuracy: 0.8965
# Epoch 00012: val_accuracy improved from 0.90111 to 0.90750, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.012.h5
# 214/214 [==============================] - 79s 369ms/step - loss: 0.3770 - accuracy: 0.8965 - val_loss: 0.3595 - val_accuracy: 0.9075 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.9069
# Epoch 00013: val_accuracy did not improve from 0.90750
# 214/214 [==============================] - 79s 369ms/step - loss: 0.3526 - accuracy: 0.9069 - val_loss: 0.3726 - val_accuracy: 0.9017 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3494 - accuracy: 0.9041
# Epoch 00014: val_accuracy did not improve from 0.90750
# 214/214 [==============================] - 79s 371ms/step - loss: 0.3494 - accuracy: 0.9041 - val_loss: 0.3762 - val_accuracy: 0.8988 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.9062
# Epoch 00015: val_accuracy improved from 0.90750 to 0.91507, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.015.h5
# 214/214 [==============================] - 79s 371ms/step - loss: 0.3385 - accuracy: 0.9062 - val_loss: 0.3508 - val_accuracy: 0.9151 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3276 - accuracy: 0.9148
# Epoch 00016: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 80s 372ms/step - loss: 0.3276 - accuracy: 0.9148 - val_loss: 0.4235 - val_accuracy: 0.8825 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3251 - accuracy: 0.9129
# Epoch 00017: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 80s 372ms/step - loss: 0.3251 - accuracy: 0.9129 - val_loss: 0.3783 - val_accuracy: 0.8941 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.9165
# Epoch 00018: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 80s 375ms/step - loss: 0.3111 - accuracy: 0.9165 - val_loss: 0.3602 - val_accuracy: 0.9058 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3202 - accuracy: 0.9157
# Epoch 00019: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 80s 375ms/step - loss: 0.3202 - accuracy: 0.9157 - val_loss: 0.3680 - val_accuracy: 0.8935 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3067 - accuracy: 0.9168
# Epoch 00020: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 79s 371ms/step - loss: 0.3067 - accuracy: 0.9168 - val_loss: 0.3317 - val_accuracy: 0.9110 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/200
# 214/214 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9214
# Epoch 00021: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 79s 371ms/step - loss: 0.3019 - accuracy: 0.9214 - val_loss: 0.3583 - val_accuracy: 0.8970 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2836 - accuracy: 0.9277
# Epoch 00022: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 79s 368ms/step - loss: 0.2836 - accuracy: 0.9277 - val_loss: 0.4330 - val_accuracy: 0.8650 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.9240
# Epoch 00023: val_accuracy did not improve from 0.91507
# 214/214 [==============================] - 79s 368ms/step - loss: 0.2835 - accuracy: 0.9240 - val_loss: 0.3402 - val_accuracy: 0.9081 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9313
# Epoch 00024: val_accuracy improved from 0.91507 to 0.92554, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.024.h5
# 214/214 [==============================] - 79s 370ms/step - loss: 0.2732 - accuracy: 0.9313 - val_loss: 0.3121 - val_accuracy: 0.9255 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.9291
# Epoch 00025: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 368ms/step - loss: 0.2779 - accuracy: 0.9291 - val_loss: 0.3282 - val_accuracy: 0.9168 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.9279
# Epoch 00026: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 370ms/step - loss: 0.2695 - accuracy: 0.9279 - val_loss: 0.3368 - val_accuracy: 0.9058 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.9317
# Epoch 00027: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 369ms/step - loss: 0.2617 - accuracy: 0.9317 - val_loss: 0.3400 - val_accuracy: 0.9133 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.9332
# Epoch 00028: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 370ms/step - loss: 0.2647 - accuracy: 0.9332 - val_loss: 0.3236 - val_accuracy: 0.9162 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9303
# Epoch 00029: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 373ms/step - loss: 0.2585 - accuracy: 0.9303 - val_loss: 0.3237 - val_accuracy: 0.9127 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 30/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.9294
# Epoch 00030: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 372ms/step - loss: 0.2630 - accuracy: 0.9294 - val_loss: 0.3628 - val_accuracy: 0.9052 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9357
# Epoch 00031: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 373ms/step - loss: 0.2476 - accuracy: 0.9357 - val_loss: 0.5298 - val_accuracy: 0.8586 - lr: 0.0010
# Learning rate:  0.001
# Epoch 32/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.9398
# Epoch 00032: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 376ms/step - loss: 0.2451 - accuracy: 0.9398 - val_loss: 0.3159 - val_accuracy: 0.9232 - lr: 0.0010
# Learning rate:  0.001
# Epoch 33/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9399
# Epoch 00033: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 81s 377ms/step - loss: 0.2430 - accuracy: 0.9399 - val_loss: 0.2886 - val_accuracy: 0.9180 - lr: 0.0010
# Learning rate:  0.001
# Epoch 34/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9389
# Epoch 00034: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 374ms/step - loss: 0.2414 - accuracy: 0.9389 - val_loss: 0.4182 - val_accuracy: 0.8802 - lr: 0.0010
# Learning rate:  0.001
# Epoch 35/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9385
# Epoch 00035: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 376ms/step - loss: 0.2448 - accuracy: 0.9385 - val_loss: 0.3156 - val_accuracy: 0.9116 - lr: 0.0010
# Learning rate:  0.001
# Epoch 36/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9453
# Epoch 00036: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 375ms/step - loss: 0.2301 - accuracy: 0.9453 - val_loss: 0.2894 - val_accuracy: 0.9238 - lr: 0.0010
# Learning rate:  0.001
# Epoch 37/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9445
# Epoch 00037: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 375ms/step - loss: 0.2310 - accuracy: 0.9445 - val_loss: 0.3633 - val_accuracy: 0.9034 - lr: 0.0010
# Learning rate:  0.001
# Epoch 38/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9423
# Epoch 00038: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 371ms/step - loss: 0.2346 - accuracy: 0.9423 - val_loss: 0.2932 - val_accuracy: 0.9209 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 39/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9467
# Epoch 00039: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 368ms/step - loss: 0.2230 - accuracy: 0.9467 - val_loss: 0.3258 - val_accuracy: 0.9081 - lr: 0.0010
# Learning rate:  0.001
# Epoch 40/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9474
# Epoch 00040: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 367ms/step - loss: 0.2200 - accuracy: 0.9474 - val_loss: 0.3460 - val_accuracy: 0.9116 - lr: 0.0010
# Learning rate:  0.001
# Epoch 41/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9468
# Epoch 00041: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 371ms/step - loss: 0.2233 - accuracy: 0.9468 - val_loss: 0.3095 - val_accuracy: 0.9255 - lr: 0.0010
# Learning rate:  0.001
# Epoch 42/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9499
# Epoch 00042: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 375ms/step - loss: 0.2150 - accuracy: 0.9499 - val_loss: 0.2856 - val_accuracy: 0.9238 - lr: 0.0010
# Learning rate:  0.001
# Epoch 43/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9502
# Epoch 00043: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 80s 373ms/step - loss: 0.2095 - accuracy: 0.9502 - val_loss: 0.3208 - val_accuracy: 0.9063 - lr: 0.0010
# Learning rate:  0.001
# Epoch 44/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9467
# Epoch 00044: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 79s 371ms/step - loss: 0.2209 - accuracy: 0.9467 - val_loss: 0.3368 - val_accuracy: 0.9197 - lr: 0.0010
# Learning rate:  0.001
# Epoch 45/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2090 - accuracy: 0.9525
# Epoch 00045: val_accuracy improved from 0.92554 to 0.93136, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.045.h5
# 214/214 [==============================] - 80s 374ms/step - loss: 0.2090 - accuracy: 0.9525 - val_loss: 0.2732 - val_accuracy: 0.9314 - lr: 0.0010
# Learning rate:  0.001
# Epoch 46/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9524
# Epoch 00046: val_accuracy did not improve from 0.93136
# 214/214 [==============================] - 79s 370ms/step - loss: 0.2049 - accuracy: 0.9524 - val_loss: 0.4359 - val_accuracy: 0.8918 - lr: 0.0010
# Learning rate:  0.001
# Epoch 47/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9519
# Epoch 00047: val_accuracy improved from 0.93136 to 0.93194, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.047.h5
# 214/214 [==============================] - 80s 373ms/step - loss: 0.2093 - accuracy: 0.9519 - val_loss: 0.2800 - val_accuracy: 0.9319 - lr: 0.0010
# Learning rate:  0.001
# Epoch 48/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9509
# Epoch 00048: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 79s 370ms/step - loss: 0.2104 - accuracy: 0.9509 - val_loss: 0.3280 - val_accuracy: 0.9168 - lr: 0.0010
# Learning rate:  0.001
# Epoch 49/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9531
# Epoch 00049: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 372ms/step - loss: 0.2017 - accuracy: 0.9531 - val_loss: 0.2975 - val_accuracy: 0.9197 - lr: 0.0010
# Learning rate:  0.001
# Epoch 50/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9572
# Epoch 00050: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 372ms/step - loss: 0.1945 - accuracy: 0.9572 - val_loss: 0.3123 - val_accuracy: 0.9215 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 51/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9535
# Epoch 00051: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 375ms/step - loss: 0.2018 - accuracy: 0.9535 - val_loss: 0.2870 - val_accuracy: 0.9261 - lr: 0.0010
# Learning rate:  0.001
# Epoch 52/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9557
# Epoch 00052: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 375ms/step - loss: 0.2012 - accuracy: 0.9557 - val_loss: 0.2946 - val_accuracy: 0.9238 - lr: 0.0010
# Learning rate:  0.001
# Epoch 53/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1934 - accuracy: 0.9556
# Epoch 00053: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 81s 376ms/step - loss: 0.1934 - accuracy: 0.9556 - val_loss: 0.3415 - val_accuracy: 0.9162 - lr: 0.0010
# Learning rate:  0.001
# Epoch 54/200
# 214/214 [==============================] - ETA: 0s - loss: 0.2007 - accuracy: 0.9543
# Epoch 00054: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 375ms/step - loss: 0.2007 - accuracy: 0.9543 - val_loss: 0.2647 - val_accuracy: 0.9308 - lr: 0.0010
# Learning rate:  0.001
# Epoch 55/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9572
# Epoch 00055: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 79s 371ms/step - loss: 0.1915 - accuracy: 0.9572 - val_loss: 0.3077 - val_accuracy: 0.9226 - lr: 0.0010
# Learning rate:  0.001
# Epoch 56/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9582
# Epoch 00056: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 375ms/step - loss: 0.1935 - accuracy: 0.9582 - val_loss: 0.3010 - val_accuracy: 0.9302 - lr: 0.0010
# Learning rate:  0.001
# Epoch 57/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9537
# Epoch 00057: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 81s 377ms/step - loss: 0.1971 - accuracy: 0.9537 - val_loss: 0.3577 - val_accuracy: 0.9058 - lr: 0.0010
# Learning rate:  0.001
# Epoch 58/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9595
# Epoch 00058: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 81s 377ms/step - loss: 0.1921 - accuracy: 0.9595 - val_loss: 0.2885 - val_accuracy: 0.9284 - lr: 0.0010
# Learning rate:  0.001
# Epoch 59/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9623
# Epoch 00059: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 374ms/step - loss: 0.1818 - accuracy: 0.9623 - val_loss: 0.3462 - val_accuracy: 0.9104 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 60/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1864 - accuracy: 0.9594
# Epoch 00060: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 373ms/step - loss: 0.1864 - accuracy: 0.9594 - val_loss: 0.3372 - val_accuracy: 0.9063 - lr: 0.0010
# Learning rate:  0.001
# Epoch 61/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9652
# Epoch 00061: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 374ms/step - loss: 0.1748 - accuracy: 0.9652 - val_loss: 0.3435 - val_accuracy: 0.9110 - lr: 0.0010
# Learning rate:  0.001
# Epoch 62/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.9608
# Epoch 00062: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 372ms/step - loss: 0.1840 - accuracy: 0.9608 - val_loss: 0.2963 - val_accuracy: 0.9174 - lr: 0.0010
# Learning rate:  0.001
# Epoch 63/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9605
# Epoch 00063: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 79s 370ms/step - loss: 0.1850 - accuracy: 0.9605 - val_loss: 0.4756 - val_accuracy: 0.8674 - lr: 0.0010
# Learning rate:  0.001
# Epoch 64/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9554
# Epoch 00064: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 79s 369ms/step - loss: 0.1944 - accuracy: 0.9554 - val_loss: 0.2969 - val_accuracy: 0.9273 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 65/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9630
# Epoch 00065: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 79s 370ms/step - loss: 0.1780 - accuracy: 0.9630 - val_loss: 0.2761 - val_accuracy: 0.9284 - lr: 0.0010
# Learning rate:  0.001
# Epoch 66/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9654
# Epoch 00066: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 79s 371ms/step - loss: 0.1705 - accuracy: 0.9654 - val_loss: 0.3247 - val_accuracy: 0.9180 - lr: 0.0010
# Learning rate:  0.001
# Epoch 67/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9614
# Epoch 00067: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 373ms/step - loss: 0.1845 - accuracy: 0.9614 - val_loss: 0.3174 - val_accuracy: 0.9151 - lr: 0.0010
# Learning rate:  0.001
# Epoch 68/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9645
# Epoch 00068: val_accuracy did not improve from 0.93194
# 214/214 [==============================] - 80s 374ms/step - loss: 0.1775 - accuracy: 0.9645 - val_loss: 0.3492 - val_accuracy: 0.9127 - lr: 0.0010
# Learning rate:  0.001
# Epoch 69/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.9643
# Epoch 00069: val_accuracy improved from 0.93194 to 0.93659, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.069.h5
# 214/214 [==============================] - 81s 380ms/step - loss: 0.1735 - accuracy: 0.9643 - val_loss: 0.2777 - val_accuracy: 0.9366 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 70/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9677
# Epoch 00070: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 80s 375ms/step - loss: 0.1655 - accuracy: 0.9677 - val_loss: 0.4172 - val_accuracy: 0.9063 - lr: 0.0010
# Learning rate:  0.001
# Epoch 71/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9649
# Epoch 00071: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 81s 377ms/step - loss: 0.1740 - accuracy: 0.9649 - val_loss: 0.3561 - val_accuracy: 0.9186 - lr: 0.0010
# Learning rate:  0.001
# Epoch 72/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9640
# Epoch 00072: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 81s 377ms/step - loss: 0.1690 - accuracy: 0.9640 - val_loss: 0.3341 - val_accuracy: 0.9238 - lr: 0.0010
# Learning rate:  0.001
# Epoch 73/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1697 - accuracy: 0.9673
# Epoch 00073: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 80s 372ms/step - loss: 0.1697 - accuracy: 0.9673 - val_loss: 0.2864 - val_accuracy: 0.9284 - lr: 0.0010
# Learning rate:  0.001
# Epoch 74/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9692
# Epoch 00074: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 79s 370ms/step - loss: 0.1607 - accuracy: 0.9692 - val_loss: 0.3394 - val_accuracy: 0.9284 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 75/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9665
# Epoch 00075: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 80s 375ms/step - loss: 0.1714 - accuracy: 0.9665 - val_loss: 0.4368 - val_accuracy: 0.9092 - lr: 0.0010
# Learning rate:  0.001
# Epoch 76/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9670
# Epoch 00076: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 81s 377ms/step - loss: 0.1662 - accuracy: 0.9670 - val_loss: 0.3499 - val_accuracy: 0.9261 - lr: 0.0010
# Learning rate:  0.001
# Epoch 77/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9678
# Epoch 00077: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 82s 383ms/step - loss: 0.1655 - accuracy: 0.9678 - val_loss: 0.2816 - val_accuracy: 0.9308 - lr: 0.0010
# Learning rate:  0.001
# Epoch 78/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9620
# Epoch 00078: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 80s 373ms/step - loss: 0.1783 - accuracy: 0.9620 - val_loss: 0.2956 - val_accuracy: 0.9319 - lr: 0.0010
# Learning rate:  0.001
# Epoch 79/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9709
# Epoch 00079: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 79s 368ms/step - loss: 0.1578 - accuracy: 0.9709 - val_loss: 0.3264 - val_accuracy: 0.9255 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 80/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9728
# Epoch 00080: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 79s 371ms/step - loss: 0.1531 - accuracy: 0.9728 - val_loss: 0.3481 - val_accuracy: 0.9232 - lr: 0.0010
# Learning rate:  0.001
# Epoch 81/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9649
# Epoch 00081: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 79s 368ms/step - loss: 0.1718 - accuracy: 0.9649 - val_loss: 0.3247 - val_accuracy: 0.9174 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 82/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9792
# Epoch 00082: val_accuracy did not improve from 0.93659
# 214/214 [==============================] - 79s 369ms/step - loss: 0.1371 - accuracy: 0.9792 - val_loss: 0.2810 - val_accuracy: 0.9366 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9870
# Epoch 00083: val_accuracy improved from 0.93659 to 0.94299, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.083.h5
# 214/214 [==============================] - 79s 371ms/step - loss: 0.1188 - accuracy: 0.9870 - val_loss: 0.2760 - val_accuracy: 0.9430 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9890
# Epoch 00084: val_accuracy improved from 0.94299 to 0.94357, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.084.h5
# 214/214 [==============================] - 79s 367ms/step - loss: 0.1132 - accuracy: 0.9890 - val_loss: 0.2791 - val_accuracy: 0.9436 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 85/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9905
# Epoch 00085: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 365ms/step - loss: 0.1120 - accuracy: 0.9905 - val_loss: 0.2783 - val_accuracy: 0.9378 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 86/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9936
# Epoch 00086: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 366ms/step - loss: 0.1046 - accuracy: 0.9936 - val_loss: 0.2789 - val_accuracy: 0.9424 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9936
# Epoch 00087: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 364ms/step - loss: 0.1041 - accuracy: 0.9936 - val_loss: 0.2781 - val_accuracy: 0.9436 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/200
# 214/214 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9934
# Epoch 00088: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 365ms/step - loss: 0.1026 - accuracy: 0.9934 - val_loss: 0.2831 - val_accuracy: 0.9430 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 89/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9953
# Epoch 00089: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 364ms/step - loss: 0.0982 - accuracy: 0.9953 - val_loss: 0.2861 - val_accuracy: 0.9389 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 90/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9943
# Epoch 00090: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 362ms/step - loss: 0.0979 - accuracy: 0.9943 - val_loss: 0.2842 - val_accuracy: 0.9407 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 91/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9959
# Epoch 00091: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 78s 365ms/step - loss: 0.0937 - accuracy: 0.9959 - val_loss: 0.2892 - val_accuracy: 0.9436 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9959
# Epoch 00092: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 81s 380ms/step - loss: 0.0948 - accuracy: 0.9959 - val_loss: 0.2900 - val_accuracy: 0.9418 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 93/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9936
# Epoch 00093: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0967 - accuracy: 0.9936 - val_loss: 0.3038 - val_accuracy: 0.9366 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 94/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9972
# Epoch 00094: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 80s 373ms/step - loss: 0.0883 - accuracy: 0.9972 - val_loss: 0.3036 - val_accuracy: 0.9395 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 95/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9953
# Epoch 00095: val_accuracy did not improve from 0.94357
# 214/214 [==============================] - 79s 371ms/step - loss: 0.0893 - accuracy: 0.9953 - val_loss: 0.2978 - val_accuracy: 0.9401 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 96/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9969
# Epoch 00096: val_accuracy improved from 0.94357 to 0.94474, saving model to /content/drive/My Drive/Mineria/Train-Test 90%/./Modelos/HM_n3_ResNet20v1_model.096.h5
# 214/214 [==============================] - 79s 368ms/step - loss: 0.0865 - accuracy: 0.9969 - val_loss: 0.2982 - val_accuracy: 0.9447 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 97/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9955
# Epoch 00097: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 372ms/step - loss: 0.0881 - accuracy: 0.9955 - val_loss: 0.2968 - val_accuracy: 0.9424 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 98/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9958
# Epoch 00098: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 375ms/step - loss: 0.0870 - accuracy: 0.9958 - val_loss: 0.2941 - val_accuracy: 0.9407 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 99/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9963
# Epoch 00099: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 368ms/step - loss: 0.0849 - accuracy: 0.9963 - val_loss: 0.2927 - val_accuracy: 0.9401 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 100/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9975
# Epoch 00100: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 78s 366ms/step - loss: 0.0821 - accuracy: 0.9975 - val_loss: 0.3002 - val_accuracy: 0.9378 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 101/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9972
# Epoch 00101: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 372ms/step - loss: 0.0819 - accuracy: 0.9972 - val_loss: 0.3074 - val_accuracy: 0.9383 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 102/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9965
# Epoch 00102: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 368ms/step - loss: 0.0828 - accuracy: 0.9965 - val_loss: 0.3038 - val_accuracy: 0.9424 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 103/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9968
# Epoch 00103: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 78s 367ms/step - loss: 0.0811 - accuracy: 0.9968 - val_loss: 0.3127 - val_accuracy: 0.9395 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 104/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9978
# Epoch 00104: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 78s 366ms/step - loss: 0.0796 - accuracy: 0.9978 - val_loss: 0.3121 - val_accuracy: 0.9383 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 105/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9965
# Epoch 00105: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 369ms/step - loss: 0.0819 - accuracy: 0.9965 - val_loss: 0.3071 - val_accuracy: 0.9401 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 106/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9972
# Epoch 00106: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0788 - accuracy: 0.9972 - val_loss: 0.3168 - val_accuracy: 0.9360 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 107/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9975
# Epoch 00107: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0783 - accuracy: 0.9975 - val_loss: 0.3264 - val_accuracy: 0.9418 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 108/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9975
# Epoch 00108: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 376ms/step - loss: 0.0773 - accuracy: 0.9975 - val_loss: 0.3239 - val_accuracy: 0.9401 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 109/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9971
# Epoch 00109: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0757 - accuracy: 0.9971 - val_loss: 0.3165 - val_accuracy: 0.9401 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 110/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9982
# Epoch 00110: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0743 - accuracy: 0.9982 - val_loss: 0.3319 - val_accuracy: 0.9395 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 111/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9990
# Epoch 00111: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 375ms/step - loss: 0.0719 - accuracy: 0.9990 - val_loss: 0.3310 - val_accuracy: 0.9407 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 112/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9978
# Epoch 00112: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 372ms/step - loss: 0.0728 - accuracy: 0.9978 - val_loss: 0.3284 - val_accuracy: 0.9412 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 113/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9977
# Epoch 00113: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 371ms/step - loss: 0.0725 - accuracy: 0.9977 - val_loss: 0.3283 - val_accuracy: 0.9407 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 114/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0721 - accuracy: 0.9974
# Epoch 00114: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 369ms/step - loss: 0.0721 - accuracy: 0.9974 - val_loss: 0.3412 - val_accuracy: 0.9366 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 115/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9984
# Epoch 00115: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 78s 366ms/step - loss: 0.0705 - accuracy: 0.9984 - val_loss: 0.3343 - val_accuracy: 0.9378 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 116/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9982
# Epoch 00116: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 78s 367ms/step - loss: 0.0713 - accuracy: 0.9982 - val_loss: 0.3245 - val_accuracy: 0.9372 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 117/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0701 - accuracy: 0.9985
# Epoch 00117: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 370ms/step - loss: 0.0701 - accuracy: 0.9985 - val_loss: 0.3399 - val_accuracy: 0.9401 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 118/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9972
# Epoch 00118: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 373ms/step - loss: 0.0711 - accuracy: 0.9972 - val_loss: 0.3486 - val_accuracy: 0.9430 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 119/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9982
# Epoch 00119: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 371ms/step - loss: 0.0687 - accuracy: 0.9982 - val_loss: 0.3347 - val_accuracy: 0.9383 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 120/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9985
# Epoch 00120: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 371ms/step - loss: 0.0678 - accuracy: 0.9985 - val_loss: 0.3306 - val_accuracy: 0.9378 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 121/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9988
# Epoch 00121: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 371ms/step - loss: 0.0665 - accuracy: 0.9988 - val_loss: 0.3194 - val_accuracy: 0.9430 - lr: 1.0000e-04
# Learning rate:  1e-05
# Epoch 122/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9987
# Epoch 00122: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 370ms/step - loss: 0.0673 - accuracy: 0.9987 - val_loss: 0.3191 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 123/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9991
# Epoch 00123: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 370ms/step - loss: 0.0655 - accuracy: 0.9991 - val_loss: 0.3199 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 124/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9987
# Epoch 00124: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 375ms/step - loss: 0.0659 - accuracy: 0.9987 - val_loss: 0.3214 - val_accuracy: 0.9430 - lr: 3.1623e-06
# Learning rate:  1e-05
# Epoch 125/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9987
# Epoch 00125: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0654 - accuracy: 0.9987 - val_loss: 0.3203 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 126/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9993
# Epoch 00126: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0653 - accuracy: 0.9993 - val_loss: 0.3207 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 127/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9990
# Epoch 00127: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0655 - accuracy: 0.9990 - val_loss: 0.3201 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 128/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9987
# Epoch 00128: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 375ms/step - loss: 0.0661 - accuracy: 0.9987 - val_loss: 0.3209 - val_accuracy: 0.9436 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 129/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9987
# Epoch 00129: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0651 - accuracy: 0.9987 - val_loss: 0.3229 - val_accuracy: 0.9430 - lr: 3.1623e-06
# Learning rate:  1e-05
# Epoch 130/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9985
# Epoch 00130: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 376ms/step - loss: 0.0651 - accuracy: 0.9985 - val_loss: 0.3231 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 131/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9993
# Epoch 00131: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 79s 371ms/step - loss: 0.0651 - accuracy: 0.9993 - val_loss: 0.3227 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 132/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9988
# Epoch 00132: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 374ms/step - loss: 0.0643 - accuracy: 0.9988 - val_loss: 0.3205 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 133/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9993
# Epoch 00133: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 376ms/step - loss: 0.0642 - accuracy: 0.9993 - val_loss: 0.3201 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 134/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9994
# Epoch 00134: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0639 - accuracy: 0.9994 - val_loss: 0.3214 - val_accuracy: 0.9442 - lr: 3.1623e-06
# Learning rate:  1e-05
# Epoch 135/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9988
# Epoch 00135: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 374ms/step - loss: 0.0644 - accuracy: 0.9988 - val_loss: 0.3203 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 136/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9994
# Epoch 00136: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 376ms/step - loss: 0.0637 - accuracy: 0.9994 - val_loss: 0.3204 - val_accuracy: 0.9442 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 137/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9991
# Epoch 00137: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0638 - accuracy: 0.9991 - val_loss: 0.3198 - val_accuracy: 0.9442 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 138/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9993
# Epoch 00138: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0642 - accuracy: 0.9993 - val_loss: 0.3213 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 139/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9990
# Epoch 00139: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0634 - accuracy: 0.9990 - val_loss: 0.3231 - val_accuracy: 0.9424 - lr: 3.1623e-06
# Learning rate:  1e-05
# Epoch 140/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9993
# Epoch 00140: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 375ms/step - loss: 0.0636 - accuracy: 0.9993 - val_loss: 0.3237 - val_accuracy: 0.9430 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 141/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9996
# Epoch 00141: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0639 - accuracy: 0.9996 - val_loss: 0.3227 - val_accuracy: 0.9442 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 142/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9990
# Epoch 00142: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 376ms/step - loss: 0.0636 - accuracy: 0.9990 - val_loss: 0.3223 - val_accuracy: 0.9447 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 143/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9996
# Epoch 00143: val_accuracy did not improve from 0.94474
# ...
# 214/214 [==============================] - ETA: 0s - loss: 0.0626 - accuracy: 0.9997
# Epoch 00152: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0626 - accuracy: 0.9997 - val_loss: 0.3301 - val_accuracy: 0.9418 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 153/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9994
# Epoch 00153: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0619 - accuracy: 0.9994 - val_loss: 0.3310 - val_accuracy: 0.9412 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 154/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0623 - accuracy: 0.9993
# Epoch 00154: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0623 - accuracy: 0.9993 - val_loss: 0.3303 - val_accuracy: 0.9412 - lr: 3.1623e-06
# Learning rate:  1e-05
# Epoch 155/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9993
# Epoch 00155: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0627 - accuracy: 0.9993 - val_loss: 0.3279 - val_accuracy: 0.9424 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 156/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9994
# Epoch 00156: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 381ms/step - loss: 0.0621 - accuracy: 0.9994 - val_loss: 0.3286 - val_accuracy: 0.9407 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 157/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9999
# Epoch 00157: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0616 - accuracy: 0.9999 - val_loss: 0.3274 - val_accuracy: 0.9407 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 158/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9993
# Epoch 00158: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 384ms/step - loss: 0.0619 - accuracy: 0.9993 - val_loss: 0.3310 - val_accuracy: 0.9389 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 159/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9994
# Epoch 00159: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 382ms/step - loss: 0.0616 - accuracy: 0.9994 - val_loss: 0.3332 - val_accuracy: 0.9401 - lr: 3.1623e-06
# Learning rate:  1e-05
# Epoch 160/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9994
# Epoch 00160: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0616 - accuracy: 0.9994 - val_loss: 0.3337 - val_accuracy: 0.9389 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 161/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9994
# Epoch 00161: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 380ms/step - loss: 0.0624 - accuracy: 0.9994 - val_loss: 0.3284 - val_accuracy: 0.9407 - lr: 1.0000e-05
# Learning rate:  1e-06
# Epoch 162/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9991
# Epoch 00162: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 380ms/step - loss: 0.0617 - accuracy: 0.9991 - val_loss: 0.3283 - val_accuracy: 0.9401 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 163/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9994
# Epoch 00163: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0612 - accuracy: 0.9994 - val_loss: 0.3284 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 164/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9993
# Epoch 00164: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0622 - accuracy: 0.9993 - val_loss: 0.3286 - val_accuracy: 0.9401 - lr: 5.0000e-07
# Learning rate:  1e-06
# Epoch 165/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9993
# Epoch 00165: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0617 - accuracy: 0.9993 - val_loss: 0.3294 - val_accuracy: 0.9401 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 166/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9990
# Epoch 00166: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 384ms/step - loss: 0.0622 - accuracy: 0.9990 - val_loss: 0.3296 - val_accuracy: 0.9401 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 167/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9994
# Epoch 00167: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0613 - accuracy: 0.9994 - val_loss: 0.3296 - val_accuracy: 0.9401 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 168/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9994
# Epoch 00168: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 385ms/step - loss: 0.0615 - accuracy: 0.9994 - val_loss: 0.3304 - val_accuracy: 0.9412 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 169/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9994
# Epoch 00169: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 83s 387ms/step - loss: 0.0610 - accuracy: 0.9994 - val_loss: 0.3301 - val_accuracy: 0.9407 - lr: 5.0000e-07
# Learning rate:  1e-06
# Epoch 170/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9997
# Epoch 00170: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 385ms/step - loss: 0.0621 - accuracy: 0.9997 - val_loss: 0.3298 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 171/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9996
# Epoch 00171: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0609 - accuracy: 0.9996 - val_loss: 0.3296 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 172/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9997
# Epoch 00172: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 382ms/step - loss: 0.0607 - accuracy: 0.9997 - val_loss: 0.3303 - val_accuracy: 0.9412 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 173/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9997
# Epoch 00173: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0609 - accuracy: 0.9997 - val_loss: 0.3299 - val_accuracy: 0.9412 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 174/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9999
# Epoch 00174: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 376ms/step - loss: 0.0603 - accuracy: 0.9999 - val_loss: 0.3302 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  1e-06
# Epoch 175/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9994
# Epoch 00175: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0616 - accuracy: 0.9994 - val_loss: 0.3300 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 176/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9999
# Epoch 00176: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 380ms/step - loss: 0.0607 - accuracy: 0.9999 - val_loss: 0.3303 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 177/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9999
# Epoch 00177: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 382ms/step - loss: 0.0604 - accuracy: 0.9999 - val_loss: 0.3305 - val_accuracy: 0.9407 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 178/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9997
# Epoch 00178: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 80s 376ms/step - loss: 0.0603 - accuracy: 0.9997 - val_loss: 0.3307 - val_accuracy: 0.9412 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 179/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9994
# Epoch 00179: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0608 - accuracy: 0.9994 - val_loss: 0.3306 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  1e-06
# Epoch 180/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9993
# Epoch 00180: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 384ms/step - loss: 0.0614 - accuracy: 0.9993 - val_loss: 0.3310 - val_accuracy: 0.9412 - lr: 1.0000e-06
# Learning rate:  1e-06
# Epoch 181/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 1.0000
# Epoch 00181: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 381ms/step - loss: 0.0605 - accuracy: 1.0000 - val_loss: 0.3311 - val_accuracy: 0.9418 - lr: 1.0000e-06
# Learning rate:  5e-07
# Epoch 182/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9994
# Epoch 00182: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 377ms/step - loss: 0.0612 - accuracy: 0.9994 - val_loss: 0.3323 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 183/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9994
# Epoch 00183: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 378ms/step - loss: 0.0618 - accuracy: 0.9994 - val_loss: 0.3320 - val_accuracy: 0.9418 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 184/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9994
# Epoch 00184: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0611 - accuracy: 0.9994 - val_loss: 0.3320 - val_accuracy: 0.9418 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 185/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9994
# Epoch 00185: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 83s 386ms/step - loss: 0.0607 - accuracy: 0.9994 - val_loss: 0.3315 - val_accuracy: 0.9418 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 186/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9990
# Epoch 00186: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0616 - accuracy: 0.9990 - val_loss: 0.3314 - val_accuracy: 0.9418 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 187/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9991
# Epoch 00187: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 380ms/step - loss: 0.0616 - accuracy: 0.9991 - val_loss: 0.3310 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 188/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9997
# Epoch 00188: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0608 - accuracy: 0.9997 - val_loss: 0.3310 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 189/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9996
# Epoch 00189: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 382ms/step - loss: 0.0607 - accuracy: 0.9996 - val_loss: 0.3317 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 190/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9996
# Epoch 00190: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 382ms/step - loss: 0.0607 - accuracy: 0.9996 - val_loss: 0.3318 - val_accuracy: 0.9401 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 191/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9994
# Epoch 00191: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0609 - accuracy: 0.9994 - val_loss: 0.3316 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 192/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9994
# Epoch 00192: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 383ms/step - loss: 0.0610 - accuracy: 0.9994 - val_loss: 0.3313 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 193/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9994
# Epoch 00193: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 382ms/step - loss: 0.0618 - accuracy: 0.9994 - val_loss: 0.3311 - val_accuracy: 0.9407 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 194/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9997
# Epoch 00194: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 83s 386ms/step - loss: 0.0610 - accuracy: 0.9997 - val_loss: 0.3315 - val_accuracy: 0.9407 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 195/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9997
# Epoch 00195: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 385ms/step - loss: 0.0607 - accuracy: 0.9997 - val_loss: 0.3310 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 196/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9991
# Epoch 00196: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0615 - accuracy: 0.9991 - val_loss: 0.3312 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 197/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9996
# Epoch 00197: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 384ms/step - loss: 0.0611 - accuracy: 0.9996 - val_loss: 0.3314 - val_accuracy: 0.9412 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 198/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9993
# Epoch 00198: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 82s 381ms/step - loss: 0.0620 - accuracy: 0.9993 - val_loss: 0.3318 - val_accuracy: 0.9407 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 199/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9997
# Epoch 00199: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 379ms/step - loss: 0.0610 - accuracy: 0.9997 - val_loss: 0.3313 - val_accuracy: 0.9407 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 200/200
# 214/214 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9996
# Epoch 00200: val_accuracy did not improve from 0.94474
# 214/214 [==============================] - 81s 380ms/step - loss: 0.0609 - accuracy: 0.9996 - val_loss: 0.3312 - val_accuracy: 0.9407 - lr: 5.0000e-07

# %%
import tensorflow as tf
import keras

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#using last check point
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model

model = load_model("/content/drive/My Drive/Mineria/Train-Test 90%/Modelos/HM_n3_ResNet20v1_model.096.h5")

# %%
# score trained model
scores = model.evaluate(x_test2,
                        y_test2,
                        batch_size=32,
                        verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 0.4004315137863159
# Test accuracy: 0.9015995860099792

# %%
prob=model.predict(x_test2)

# %%
r=[]
for i in range(y_test2.shape[0]):
  if prob[i,0]>prob[i,1]: r.append([1,0]) 
  else: r.append([0,1])

# %%
print(y_test[50])
r[50]
# Out:
# [0 1]
# [0, 1]

# %%
bien= []
mal = []
for i in  range(y_test2.shape[0]):
  if all(y_test2[i]==r[i]): 
      bien.append(i)
  else: mal.append([y_test2[i],i,prob[i,0],prob[i,1],r[i]])

# %%
table=pd.DataFrame(mal)
table.columns=["y_test","i","prob_0","prob_1","pred"]
table
# Out:
#      y_test     i    prob_0    prob_1    pred
# 0    [1, 0]     5  0.465945  0.534055  [0, 1]
# 1    [0, 1]    29  0.983521  0.016479  [1, 0]
# 2    [0, 1]    34  0.980426  0.019574  [1, 0]
# 3    [1, 0]    44  0.156689  0.843311  [0, 1]
# 4    [0, 1]    62  0.978844  0.021156  [1, 0]
# ..      ...   ...       ...       ...     ...
# 198  [1, 0]  2025  0.000204  0.999796  [0, 1]
# 199  [0, 1]  2033  0.778755  0.221245  [1, 0]
# 200  [0, 1]  2045  0.993095  0.006905  [1, 0]
# 201  [1, 0]  2058  0.066595  0.933405  [0, 1]
# 202  [1, 0]  2062  0.000041  0.999959  [0, 1]
#
# [203 rows x 5 columns]

# %%
hombres= []
mujeres= []
for i in range(table.i.shape[0]):
  if all(table.y_test[i]==[0,1]): mujeres.append(table.i[i])
  else: hombres.append(table.i[i])

# %%
hombres= []
mujeres= []
for i in bien:
  if all(y_test2[i]==[0,1]): mujeres.append(i)
  else: hombres.append(i)

# %%
len(mujeres)
# Out:
# 132

# %%
round(table.prob_0[1],2)+str(table.pred[1])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-33-3b9e6aa0df1c> in <module>()
# ----> 1 round(table.prob_0[1],2)+str(table.pred[1])
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %%
fig, axes = plt.subplots(10, 10, figsize=(14,14))
ax = axes.ravel()
w=0

# probabilidad de ser hombre 
for a in range(100,200):
  i = table.i[a]
  image = np.squeeze(x_test2[i])
  ax[w].imshow(image)
  ax[w].set_title(round(table.prob_0[a],2))
  w= w+1

fig.tight_layout()
plt.show()

# %%
print(y_test[10])
print(r[10])

image = np.squeeze(x_test[10])
plt.imshow(image)
