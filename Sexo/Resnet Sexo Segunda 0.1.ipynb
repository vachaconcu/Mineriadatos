# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from os import remove
from skimage.color import rgb2gray
from numpy import load
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from sklearn.model_selection import train_test_split
from google.colab import files
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape,ZeroPadding2D,Activation,MaxPooling2D,Dropout
from keras.layers import BatchNormalization
from keras.models import Model
from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SpatialDropout2D
from matplotlib import pyplot as plt
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D
from tensorflow.keras.layers import MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
import os
os.chdir('/content/drive/My Drive/Minería de Datos/Interna/datos')

datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/X_HM_val_int.npz') ; x_test = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/X_HM_train.npz') ; x_train = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/y_HM_val_int.npz') ; y_test = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/y_HM_train.npz') ; y_train = datos['arr_0']

datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_HM_val_ext.npz') ; y_test2 = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_HM_val_ext.npz') ; x_test2 = datos['arr_0']

# %%
print('x_test =',x_test.shape)
print('x_train =',x_train.shape)
print('y_test =',y_test.shape)
print('y_train =',y_train.shape)

print('y_test_ext=', y_test2.shape)
print('x_test_ext=', x_test2.shape)
# Out:
# x_test = (1719, 200, 200, 3)
# x_train = (6874, 200, 200, 3)
# y_test = (1719, 2)
# y_train = (6874, 2)
# y_test_ext= (2063, 2)
# x_test_ext= (2063, 200, 200, 3)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os

# %%
batch_size = 32 # orig paper trained all networks with batch_size=128
epochs = 30

data_augmentation = True
num_classes = 2
# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter para sexo c: 
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 2

# computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
model_type
# Out:
# 'ResNet20v2'

# %%
# input image dimensions.
input_shape = x_train.shape[1:]

#x_train = x_train.astype('float32') 
#x_test = x_test.astype('float32') 

# if subtract pixel mean is enabled 
# center the column-data around zero
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (6874, 200, 200, 3)
# 6874 train samples
# 1719 test samples
# y_train shape: (6874, 2)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 dropout=0.1,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
            x = Dropout(dropout)(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
            x = Dropout(dropout)(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=2, dropout=0.1):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)
    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out
# add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout)(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 200, 200, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 200, 200, 16) 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 200, 16) 272         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 200, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 200, 16) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 200, 200, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 200, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200, 200, 16) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 200, 200, 64) 1088        activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 200, 200, 64) 1088        activation_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 200, 64) 0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 200, 200, 64) 256         add[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 200, 200, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200, 200, 64) 0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 200, 200, 16) 1040        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 200, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200, 200, 16) 0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 200, 200, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 200, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200, 200, 16) 0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 200, 200, 64) 1088        activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200, 200, 64) 0           add[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 200, 64) 256         add_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 200, 200, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200, 200, 64) 0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 100, 100, 64) 4160        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 100, 100, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 100, 100, 64) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100, 100, 64) 0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 100, 100, 64) 36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 100, 64) 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 100, 100, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100, 100, 64) 0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 100, 100, 128 8320        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 100, 100, 128 8320        activation_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 100, 128 0           conv2d_11[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 100, 100, 128 512         add_2[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 100, 100, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100, 100, 128 0           dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 100, 64) 8256        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 100, 100, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 100, 100, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100, 100, 64) 0           dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 100, 100, 64) 36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 100, 100, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 100, 100, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100, 100, 64) 0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 100, 100, 128 8320        activation_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 100, 128 0           add_2[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 100, 100, 128 512         add_3[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 100, 100, 128 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100, 100, 128 0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 128)  16512       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 128)  0           dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 50, 50, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 50, 50, 128)  0           dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 256)  33024       add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 256)  33024       activation_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 256)  0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 50, 50, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 50, 256)  0           dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 128)  32896       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 50, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 50, 50, 128)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 50, 50, 128)  0           dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 256)  33024       activation_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 50, 50, 256)  0           add_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 50, 50, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 50, 50, 256)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 6, 6, 256)    0           dropout_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            18434       flatten[0][0]
# ==================================================================================================
# Total params: 589,954
# Trainable params: 586,466
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2

# %%
#using last check point
from tensorflow.keras.models import load_model

model = load_model('/content/drive/My Drive/Minería de Datos/Interna/datos/Modelos/Mujer_Primera_ResNet20v2_model.068.h5')

# %%
# prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), './Modelos')
model_name = 'Sexo_Segunda_0.7_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # fit the model on the batches generated by datagen.flow().
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, 
                        steps_per_epoch=len(x_train)//batch_size,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2624 - accuracy: 0.9179
# Epoch 00001: val_accuracy improved from -inf to 0.91332, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.001.h5
# 214/214 [==============================] - 235s 1s/step - loss: 0.2624 - accuracy: 0.9179 - val_loss: 0.2944 - val_accuracy: 0.9133 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9244
# Epoch 00002: val_accuracy improved from 0.91332 to 0.91623, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.002.h5
# 214/214 [==============================] - 230s 1s/step - loss: 0.2510 - accuracy: 0.9244 - val_loss: 0.2730 - val_accuracy: 0.9162 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9236
# Epoch 00003: val_accuracy did not improve from 0.91623
# 214/214 [==============================] - 230s 1s/step - loss: 0.2558 - accuracy: 0.9236 - val_loss: 0.3267 - val_accuracy: 0.8994 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9217
# Epoch 00004: val_accuracy improved from 0.91623 to 0.92263, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.004.h5
# 214/214 [==============================] - 230s 1s/step - loss: 0.2525 - accuracy: 0.9217 - val_loss: 0.2565 - val_accuracy: 0.9226 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9240
# Epoch 00005: val_accuracy improved from 0.92263 to 0.92554, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.005.h5
# 214/214 [==============================] - 230s 1s/step - loss: 0.2540 - accuracy: 0.9240 - val_loss: 0.2547 - val_accuracy: 0.9255 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.9300
# Epoch 00006: val_accuracy did not improve from 0.92554
# 214/214 [==============================] - 230s 1s/step - loss: 0.2471 - accuracy: 0.9300 - val_loss: 0.3074 - val_accuracy: 0.9110 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9278
# Epoch 00007: val_accuracy improved from 0.92554 to 0.92728, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.007.h5
# 214/214 [==============================] - 230s 1s/step - loss: 0.2476 - accuracy: 0.9278 - val_loss: 0.2580 - val_accuracy: 0.9273 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2468 - accuracy: 0.9277
# Epoch 00008: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 229s 1s/step - loss: 0.2468 - accuracy: 0.9277 - val_loss: 0.2634 - val_accuracy: 0.9244 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9265
# Epoch 00009: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 230s 1s/step - loss: 0.2454 - accuracy: 0.9265 - val_loss: 0.2792 - val_accuracy: 0.9186 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.9214
# Epoch 00010: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 230s 1s/step - loss: 0.2538 - accuracy: 0.9214 - val_loss: 0.3598 - val_accuracy: 0.8906 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 11/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9281
# Epoch 00011: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 230s 1s/step - loss: 0.2413 - accuracy: 0.9281 - val_loss: 0.3319 - val_accuracy: 0.9116 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9231
# Epoch 00012: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 230s 1s/step - loss: 0.2510 - accuracy: 0.9231 - val_loss: 0.2706 - val_accuracy: 0.9174 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9233
# Epoch 00013: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 230s 1s/step - loss: 0.2445 - accuracy: 0.9233 - val_loss: 0.2707 - val_accuracy: 0.9168 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.9233
# Epoch 00014: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 231s 1s/step - loss: 0.2450 - accuracy: 0.9233 - val_loss: 0.2904 - val_accuracy: 0.9186 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9304
# Epoch 00015: val_accuracy did not improve from 0.92728
# 214/214 [==============================] - 230s 1s/step - loss: 0.2408 - accuracy: 0.9304 - val_loss: 0.3718 - val_accuracy: 0.8877 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 16/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9234
# Epoch 00016: val_accuracy improved from 0.92728 to 0.92961, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.016.h5
# 214/214 [==============================] - 231s 1s/step - loss: 0.2503 - accuracy: 0.9234 - val_loss: 0.2552 - val_accuracy: 0.9296 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.9237
# Epoch 00017: val_accuracy did not improve from 0.92961
# 214/214 [==============================] - 230s 1s/step - loss: 0.2458 - accuracy: 0.9237 - val_loss: 0.2839 - val_accuracy: 0.9255 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2364 - accuracy: 0.9301
# Epoch 00018: val_accuracy did not improve from 0.92961
# 214/214 [==============================] - 231s 1s/step - loss: 0.2364 - accuracy: 0.9301 - val_loss: 0.2728 - val_accuracy: 0.9250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2375 - accuracy: 0.9284
# Epoch 00019: val_accuracy did not improve from 0.92961
# 214/214 [==============================] - 230s 1s/step - loss: 0.2375 - accuracy: 0.9284 - val_loss: 0.3101 - val_accuracy: 0.9127 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9268
# Epoch 00020: val_accuracy improved from 0.92961 to 0.93019, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.020.h5
# 214/214 [==============================] - 231s 1s/step - loss: 0.2403 - accuracy: 0.9268 - val_loss: 0.2623 - val_accuracy: 0.9302 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 21/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9303
# Epoch 00021: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2414 - accuracy: 0.9303 - val_loss: 0.2762 - val_accuracy: 0.9226 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9281
# Epoch 00022: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2415 - accuracy: 0.9281 - val_loss: 0.3075 - val_accuracy: 0.9145 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2365 - accuracy: 0.9293
# Epoch 00023: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2365 - accuracy: 0.9293 - val_loss: 0.2911 - val_accuracy: 0.9151 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9322
# Epoch 00024: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2324 - accuracy: 0.9322 - val_loss: 0.2738 - val_accuracy: 0.9250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9306
# Epoch 00025: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2435 - accuracy: 0.9306 - val_loss: 0.2596 - val_accuracy: 0.9296 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 26/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9320
# Epoch 00026: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2345 - accuracy: 0.9320 - val_loss: 0.2821 - val_accuracy: 0.9139 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9315
# Epoch 00027: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2344 - accuracy: 0.9315 - val_loss: 0.2978 - val_accuracy: 0.9127 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.9348
# Epoch 00028: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2285 - accuracy: 0.9348 - val_loss: 0.2630 - val_accuracy: 0.9290 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9325
# Epoch 00029: val_accuracy did not improve from 0.93019
# 214/214 [==============================] - 230s 1s/step - loss: 0.2322 - accuracy: 0.9325 - val_loss: 0.2663 - val_accuracy: 0.9203 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/30
# 214/214 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9335
# Epoch 00030: val_accuracy improved from 0.93019 to 0.93834, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Sexo_Segunda_0.7_ResNet20v2_model.030.h5
# 214/214 [==============================] - 231s 1s/step - loss: 0.2308 - accuracy: 0.9335 - val_loss: 0.2371 - val_accuracy: 0.9383 - lr: 0.0010

# %%
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
