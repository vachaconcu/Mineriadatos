# %% [markdown]
# <a href="https://colab.research.google.com/github/vachaconcu/Mineriadatos/blob/master/CargaDatos_uno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from skimage.color import rgb2gray
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img

# %%
tar = tarfile.open('/content/drive/My Drive/Mineria/uno.tar.gz')
tar.extractall()

# %%
os.chdir("/content/uno")

# %%
at = pd.read_csv('/content/drive/My Drive/Mineria/uno.csv')
at
# Out:
#        Unnamed: 0                                     id  mujer  edad  raza
# 0               1   1_0_0_20161219140627985.jpg.chip.jpg      0     1     0
# 1               2   1_0_0_20161219140642920.jpg.chip.jpg      0     1     0
# 2               3   1_0_0_20161219154018476.jpg.chip.jpg      0     1     0
# 3               4   1_0_0_20161219154556757.jpg.chip.jpg      0     1     0
# 4               5   1_0_0_20161219160713534.jpg.chip.jpg      0     1     0
# ...           ...                                    ...    ...   ...   ...
# 11848       11849  96_1_2_20170110182504813.jpg.chip.jpg      1    96     2
# 11849       11850  96_1_2_20170110183528193.jpg.chip.jpg      1    96     2
# 11850       11851  99_0_0_20170117195137161.jpg.chip.jpg      0    99     0
# 11851       11852  99_1_0_20170120133837030.jpg.chip.jpg      1    99     0
# 11852       11853  99_1_1_20170120134639935.jpg.chip.jpg      1    99     1
#
# [11853 rows x 5 columns]

# %%
i=15
print(at.id[i])
image=io.imread(at.id[i])
plt.imshow(image)

Idata=np.array(image)
print("\nLa imagen tiene forma: ",Idata.shape,"\n")
print(Idata)
# Out:
# 1_0_0_20161219200250923.jpg.chip.jpg
#
# La imagen tiene forma:  (200, 200, 3)
#
# [[[166 130  98]
#   [165 129  97]
#   [161 125  93]
#   ...
#   [247 230 222]
#   [247 230 222]
#   [244 227 219]]
#
#  [[167 131  99]
#   [166 130  98]
#   [163 127  95]
#   ...
#   [247 230 222]
#   [247 230 222]
#   [244 227 219]]
#
#  [[169 133 101]
#   [169 133 101]
#   [167 131  99]
#   ...
#   [247 230 222]
#   [247 230 222]
#   [245 228 220]]
#
#  ...
#
#  [[191 141 114]
#   [190 140 113]
#   [189 139 112]
#   ...
#   [240 210 199]
#   [241 211 200]
#   [241 211 200]]
#
#  [[191 141 114]
#   [191 141 114]
#   [190 140 113]
#   ...
#   [241 211 200]
#   [241 211 200]
#   [240 212 200]]
#
#  [[191 141 114]
#   [191 141 114]
#   [190 140 113]
#   ...
#   [241 211 200]
#   [240 212 200]
#   [240 212 200]]]

# %%
for i in range(2005,2010): 
    x=at.id[i]
    image=io.imread(x)
    print(image.shape)
# Out:
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)
# (200, 200, 3)

# %%
dataset_array2 = []

for i in range(at.shape[0]):
  img = load_img(at.id[i])
  img_array = img_to_array(img)
  dataset_array2.append(img_array)

# %%
dataset_array2 = np.array(dataset_array2)

# %%
dataset_array2[11852]
# Out:
# array([[[ 25.,  26.,  21.],
#         [ 24.,  25.,  20.],
#         [ 24.,  25.,  20.],
#         ...,
#         [190., 156., 129.],
#         [189., 155., 128.],
#         [189., 155., 128.]],
#
#        [[ 24.,  25.,  20.],
#         [ 24.,  25.,  20.],
#         [ 24.,  25.,  20.],
#         ...,
#         [186., 152., 125.],
#         [184., 150., 123.],
#         [184., 150., 123.]],
#
#        [[ 23.,  24.,  19.],
#         [ 23.,  24.,  19.],
#         [ 23.,  24.,  19.],
#         ...,
#         [180., 146., 119.],
#         [179., 145., 118.],
#         [178., 144., 117.]],
#
#        ...,
#
#        [[ 20.,  17.,  10.],
#         [ 19.,  16.,   9.],
#         [ 17.,  17.,   9.],
#         ...,
#         [120.,  89.,  69.],
#         [119.,  88.,  68.],
#         [119.,  88.,  67.]],
#
#        [[ 19.,  16.,   9.],
#         [ 18.,  15.,   8.],
#         [ 16.,  16.,   8.],
#         ...,
#         [122.,  91.,  71.],
#         [121.,  90.,  70.],
#         [119.,  88.,  67.]],
#
#        [[ 18.,  15.,   8.],
#         [ 18.,  15.,   8.],
#         [ 15.,  15.,   7.],
#         ...,
#         [124.,  93.,  73.],
#         [121.,  90.,  70.],
#         [119.,  88.,  67.]]], dtype=float32)

# %%
type(dataset_array2)
dataset_array2.shape
# Out:
# (11853, 200, 200, 3)

# %%
dataset_array2.resize((11853,200*200*3)) 
dataset_array2[237]
# Out:
# array([ 91.,  85.,  97., ..., 133., 172., 201.], dtype=float32)

# %%
dataset_array2[11852].reshape((200,200,3))
# Out:
# array([[[ 25.,  26.,  21.],
#         [ 24.,  25.,  20.],
#         [ 24.,  25.,  20.],
#         ...,
#         [190., 156., 129.],
#         [189., 155., 128.],
#         [189., 155., 128.]],
#
#        [[ 24.,  25.,  20.],
#         [ 24.,  25.,  20.],
#         [ 24.,  25.,  20.],
#         ...,
#         [186., 152., 125.],
#         [184., 150., 123.],
#         [184., 150., 123.]],
#
#        [[ 23.,  24.,  19.],
#         [ 23.,  24.,  19.],
#         [ 23.,  24.,  19.],
#         ...,
#         [180., 146., 119.],
#         [179., 145., 118.],
#         [178., 144., 117.]],
#
#        ...,
#
#        [[ 20.,  17.,  10.],
#         [ 19.,  16.,   9.],
#         [ 17.,  17.,   9.],
#         ...,
#         [120.,  89.,  69.],
#         [119.,  88.,  68.],
#         [119.,  88.,  67.]],
#
#        [[ 19.,  16.,   9.],
#         [ 18.,  15.,   8.],
#         [ 16.,  16.,   8.],
#         ...,
#         [122.,  91.,  71.],
#         [121.,  90.,  70.],
#         [119.,  88.,  67.]],
#
#        [[ 18.,  15.,   8.],
#         [ 18.,  15.,   8.],
#         [ 15.,  15.,   7.],
#         ...,
#         [124.,  93.,  73.],
#         [121.,  90.,  70.],
#         [119.,  88.,  67.]]], dtype=float32)

# %%
import tensorflow as tf
dataset_array2=dataset_array2/255.

# %%
dataset_array2[118].reshape((200,200,3))
# Out:
# array([[[0.6745098 , 0.57254905, 0.48235294],
#         [0.6784314 , 0.5764706 , 0.4862745 ],
#         [0.6862745 , 0.5803922 , 0.49803922],
#         ...,
#         [0.85882354, 0.7411765 , 0.70980394],
#         [0.8627451 , 0.74509805, 0.7137255 ],
#         [0.8627451 , 0.74509805, 0.7137255 ]],
#
#        [[0.6784314 , 0.5764706 , 0.4862745 ],
#         [0.68235296, 0.5803922 , 0.49019608],
#         [0.6862745 , 0.5803922 , 0.49803922],
#         ...,
#         [0.8627451 , 0.74509805, 0.7137255 ],
#         [0.8627451 , 0.74509805, 0.7137255 ],
#         [0.8666667 , 0.7490196 , 0.7176471 ]],
#
#        [[0.6784314 , 0.5764706 , 0.4862745 ],
#         [0.68235296, 0.5803922 , 0.49019608],
#         [0.6901961 , 0.58431375, 0.5019608 ],
#         ...,
#         [0.8666667 , 0.7490196 , 0.7176471 ],
#         [0.8666667 , 0.7490196 , 0.7176471 ],
#         [0.87058824, 0.7529412 , 0.72156864]],
#
#        ...,
#
#        [[0.7372549 , 0.67058825, 0.56078434],
#         [0.7137255 , 0.64705884, 0.5372549 ],
#         [0.6666667 , 0.6       , 0.49803922],
#         ...,
#         [0.8235294 , 0.77254903, 0.7058824 ],
#         [0.8       , 0.7372549 , 0.6745098 ],
#         [0.7764706 , 0.7137255 , 0.654902  ]],
#
#        [[0.73333335, 0.6666667 , 0.5568628 ],
#         [0.7058824 , 0.6392157 , 0.5294118 ],
#         [0.654902  , 0.5882353 , 0.4862745 ],
#         ...,
#         [0.77254903, 0.72156864, 0.654902  ],
#         [0.7490196 , 0.6862745 , 0.62352943],
#         [0.7294118 , 0.6666667 , 0.60784316]],
#
#        [[0.7294118 , 0.6627451 , 0.5529412 ],
#         [0.69803923, 0.6313726 , 0.52156866],
#         [0.6431373 , 0.5764706 , 0.4745098 ],
#         ...,
#         [0.7176471 , 0.6666667 , 0.6       ],
#         [0.7058824 , 0.6431373 , 0.5803922 ],
#         [0.69411767, 0.6313726 , 0.57254905]]], dtype=float32)

# %%
from numpy import asarray
from numpy import savez_compressed
savez_compressed('/content/drive/My Drive/Mineria/datos_uno.npz',dataset_array2)

# %%
from numpy import load
#dict_data = load('/content/drive/My Drive/Mineria/datos_uno.npz')
#datos = dict_data['arr_0']
datos=datos.reshape((11853,200,200,3))
datos.shape
# Out:
# (11853, 200, 200, 3)

# %%
i=15
print(at.id[i])
image = np.squeeze(datos[i])
plt.imshow(image)

Idata=np.array(image)
print("\nLa imagen tiene forma: ",Idata.shape,"\n")
print(Idata)
# Out:
# 1_0_0_20161219200250923.jpg.chip.jpg
#
# La imagen tiene forma:  (200, 200, 3)
#
# [[[0.6509804  0.50980395 0.38431373]
#   [0.64705884 0.5058824  0.38039216]
#   [0.6313726  0.49019608 0.3647059 ]
#   ...
#   [0.96862745 0.9019608  0.87058824]
#   [0.96862745 0.9019608  0.87058824]
#   [0.95686275 0.8901961  0.85882354]]
#
#  [[0.654902   0.5137255  0.3882353 ]
#   [0.6509804  0.50980395 0.38431373]
#   [0.6392157  0.49803922 0.37254903]
#   ...
#   [0.96862745 0.9019608  0.87058824]
#   [0.96862745 0.9019608  0.87058824]
#   [0.95686275 0.8901961  0.85882354]]
#
#  [[0.6627451  0.52156866 0.39607844]
#   [0.6627451  0.52156866 0.39607844]
#   [0.654902   0.5137255  0.3882353 ]
#   ...
#   [0.96862745 0.9019608  0.87058824]
#   [0.96862745 0.9019608  0.87058824]
#   [0.9607843  0.89411765 0.8627451 ]]
#
#  ...
#
#  [[0.7490196  0.5529412  0.44705883]
#   [0.74509805 0.54901963 0.44313726]
#   [0.7411765  0.54509807 0.4392157 ]
#   ...
#   [0.9411765  0.8235294  0.78039217]
#   [0.94509804 0.827451   0.78431374]
#   [0.94509804 0.827451   0.78431374]]
#
#  [[0.7490196  0.5529412  0.44705883]
#   [0.7490196  0.5529412  0.44705883]
#   [0.74509805 0.54901963 0.44313726]
#   ...
#   [0.94509804 0.827451   0.78431374]
#   [0.94509804 0.827451   0.78431374]
#   [0.9411765  0.83137256 0.78431374]]
#
#  [[0.7490196  0.5529412  0.44705883]
#   [0.7490196  0.5529412  0.44705883]
#   [0.74509805 0.54901963 0.44313726]
#   ...
#   [0.94509804 0.827451   0.78431374]
#   [0.9411765  0.83137256 0.78431374]
#   [0.9411765  0.83137256 0.78431374]]]

# %%
fig, axes = plt.subplots(5, 10, figsize=(16,16))
ax = axes.ravel()

for i in range(0,50):
  image = np.squeeze(datos[i])
  ax[i].imshow(image)
  ax[i].set_title(i)

fig.tight_layout()
plt.show()

# %%
at.id[35]
# Out:
# '1_0_0_20170109193052283.jpg.chip.jpg'

# %%
fig, axes = plt.subplots(3, 10, figsize=(16,16))
ax = axes.ravel()

for i in range(11823,11853):
  image = np.squeeze(datos[i])
  ax[i-11823].imshow(image)
  ax[i-11823].set_title(at.edad[i])

fig.tight_layout()
plt.show()
