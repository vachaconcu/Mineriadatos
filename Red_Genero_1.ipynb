# %% [markdown]
# <a href="https://colab.research.google.com/github/vachaconcu/Mineriadatos/blob/master/Red_Genero_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from os import remove
from skimage.color import rgb2gray
from numpy import load
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from sklearn.model_selection import train_test_split
from google.colab import files
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape,ZeroPadding2D,Activation,MaxPooling2D,Dropout
from keras.layers import BatchNormalization
from keras.models import Model
from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SpatialDropout2D
from matplotlib import pyplot as plt
import keras
# Out:
# Using TensorFlow backend.

# %%
datos= load('/content/drive/My Drive/Mineria/X_test.npz') ; X_test = datos['arr_0']

# %%
datos= load('/content/drive/My Drive/Mineria/X_train.npz') ; X_train = datos['arr_0']

# %%
datos= load('/content/drive/My Drive/Mineria/y_test_mujer.npz') ; y_test = datos['arr_0']

# %%
datos= load('/content/drive/My Drive/Mineria/y_train_mujer.npz') ; y_train = datos['arr_0']

# %%
print(X_test.shape)
print(y_test.shape)
print(X_train.shape)
print(y_train.shape)
# Out:
# (1185, 200, 200, 3)
# (1185, 2)
# (10661, 200, 200, 3)
# (10661, 2)

# %%
def model(input_shape):
    # Define the input placeholder. 
    X_input = Input(input_shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(16, (3, 3),padding='same',name='Conv16')(X) 
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    
    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool_1')(X)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (3, 3),padding='same',name='Conv32')(X) 
    X = BatchNormalization(axis = 3,)(X)
    X = Dropout(0.5)(X)
    X = Activation('relu')(X)
    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool_2')(X)

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(64, (3, 3),padding='same',name='Conv64')(X) 
    X = BatchNormalization(axis = 3)(X)
    X = Dropout(0.5)(X)
    X = Activation('relu')(X)
       
    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool_3')(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dropout(0.5)(X)
    X = Dense(2, activation='sigmoid', name='final')(X)

    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='Sexo_Model')
    
    return model

# %%
Modelo = model((200,200,3))
plot_model(Modelo)

# %%
Modelo.summary()
# Out:
# Model: "Sexo_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 200, 200, 3)       0
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 206, 206, 3)       0
# _________________________________________________________________
# Conv16 (Conv2D)              (None, 206, 206, 16)      448
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 206, 206, 16)      64
# _________________________________________________________________
# activation_4 (Activation)    (None, 206, 206, 16)      0
# _________________________________________________________________
# max_pool_1 (MaxPooling2D)    (None, 103, 103, 16)      0
# _________________________________________________________________
# Conv32 (Conv2D)              (None, 103, 103, 32)      4640
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 103, 103, 32)      128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 103, 103, 32)      0
# _________________________________________________________________
# activation_5 (Activation)    (None, 103, 103, 32)      0
# _________________________________________________________________
# max_pool_2 (MaxPooling2D)    (None, 51, 51, 32)        0
# _________________________________________________________________
# Conv64 (Conv2D)              (None, 51, 51, 64)        18496
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 51, 51, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 51, 51, 64)        0
# _________________________________________________________________
# activation_6 (Activation)    (None, 51, 51, 64)        0
# _________________________________________________________________
# max_pool_3 (MaxPooling2D)    (None, 25, 25, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 40000)             0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 40000)             0
# _________________________________________________________________
# final (Dense)                (None, 2)                 80002
# =================================================================
# Total params: 104,034
# Trainable params: 103,810
# Non-trainable params: 224
# _________________________________________________________________

# %%
Modelo.compile(optimizer = "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
history= Modelo.fit(x = X_train,y = y_train,validation_data=(X_test,y_test),epochs =40 ,batch_size = 32)
# Out:
# Train on 10661 samples, validate on 1185 samples
# Epoch 1/40
# 10661/10661 [==============================] - 627s 59ms/step - loss: 0.3130 - accuracy: 0.8651 - val_loss: 0.3206 - val_accuracy: 0.8688
# Epoch 2/40
# 10661/10661 [==============================] - 628s 59ms/step - loss: 0.2829 - accuracy: 0.8811 - val_loss: 0.3532 - val_accuracy: 0.8380
# Epoch 3/40
# 10661/10661 [==============================] - 630s 59ms/step - loss: 0.2623 - accuracy: 0.8911 - val_loss: 0.2936 - val_accuracy: 0.8886
# Epoch 4/40
# 10661/10661 [==============================] - 634s 59ms/step - loss: 0.2338 - accuracy: 0.9067 - val_loss: 0.3004 - val_accuracy: 0.8785
# Epoch 24/40
# 10661/10661 [==============================] - 666s 63ms/step - loss: 0.0785 - accuracy: 0.9715 - val_loss: 0.2800 - val_accuracy: 0.8911
# Epoch 25/40
# 10661/10661 [==============================] - 672s 63ms/step - loss: 0.0778 - accuracy: 0.9712 - val_loss: 0.3125 - val_accuracy: 0.8726
# Epoch 26/40
# 10661/10661 [==============================] - 668s 63ms/step - loss: 0.0706 - accuracy: 0.9728 - val_loss: 0.3870 - val_accuracy: 0.8536
# Epoch 27/40
# 10661/10661 [==============================] - 678s 64ms/step - loss: 0.0699 - accuracy: 0.9747 - val_loss: 0.3556 - val_accuracy: 0.8776
# Epoch 28/40
# 10661/10661 [==============================] - 691s 65ms/step - loss: 0.0776 - accuracy: 0.9714 - val_loss: 0.2979 - val_accuracy: 0.8743
# Epoch 29/40
# 10661/10661 [==============================] - 684s 64ms/step - loss: 0.0678 - accuracy: 0.9750 - val_loss: 0.2999 - val_accuracy: 0.8895
# Epoch 30/40
# 10661/10661 [==============================] - 677s 64ms/step - loss: 0.0639 - accuracy: 0.9752 - val_loss: 0.3274 - val_accuracy: 0.8797
# Epoch 31/40
# 10661/10661 [==============================] - 671s 63ms/step - loss: 0.0639 - accuracy: 0.9768 - val_loss: 0.3291 - val_accuracy: 0.8759
# Epoch 32/40
# 10661/10661 [==============================] - 659s 62ms/step - loss: 0.0652 - accuracy: 0.9749 - val_loss: 0.3308 - val_accuracy: 0.8730
# Epoch 33/40
# 10661/10661 [==============================] - 651s 61ms/step - loss: 0.0598 - accuracy: 0.9787 - val_loss: 0.3400 - val_accuracy: 0.8684
# Epoch 34/40
# 10661/10661 [==============================] - 649s 61ms/step - loss: 0.0585 - accuracy: 0.9795 - val_loss: 0.3440 - val_accuracy: 0.8781
# Epoch 35/40
# 10661/10661 [==============================] - 654s 61ms/step - loss: 0.0583 - accuracy: 0.9796 - val_loss: 0.3208 - val_accuracy: 0.8814
# Epoch 36/40
# 10661/10661 [==============================] - 645s 60ms/step - loss: 0.0555 - accuracy: 0.9796 - val_loss: 0.3460 - val_accuracy: 0.8726
# Epoch 37/40
# 10661/10661 [==============================] - 644s 60ms/step - loss: 0.0546 - accuracy: 0.9804 - val_loss: 0.3253 - val_accuracy: 0.8878
# Epoch 38/40
# 10661/10661 [==============================] - 642s 60ms/step - loss: 0.0547 - accuracy: 0.9806 - val_loss: 0.3320 - val_accuracy: 0.8759
# Epoch 39/40
# 10661/10661 [==============================] - 642s 60ms/step - loss: 0.0494 - accuracy: 0.9826 - val_loss: 0.3117 - val_accuracy: 0.8819
# Epoch 40/40
# 10661/10661 [==============================] - 637s 60ms/step - loss: 0.0565 - accuracy: 0.9803 - val_loss: 0.3544 - val_accuracy: 0.8726

# %%
preds = Modelo.evaluate(x = X_test,y = y_test)
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 1185/1185 [==============================] - 23s 19ms/step
#
# Loss = 0.3543568713755547
# Test Accuracy = 0.8725738525390625

# %%
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#print(model.predict(x))

# %%
Modelo.save('/content/drive/My Drive/Mineria.modelo1_sexo.h5')

# %%
Modelo = keras.models.load_model('/content/drive/My Drive/Mineria.my_model.h5')
