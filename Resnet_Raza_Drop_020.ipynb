# %% [markdown]
# <a href="https://colab.research.google.com/github/vachaconcu/Mineriadatos/blob/master/Resnet_Raza_Drop_020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from os import remove
from skimage.color import rgb2gray
from numpy import load
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from sklearn.model_selection import train_test_split
from google.colab import files
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape,ZeroPadding2D,Activation,MaxPooling2D,Dropout
from keras.layers import BatchNormalization
from keras.models import Model
from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SpatialDropout2D
from matplotlib import pyplot as plt
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D
from tensorflow.keras.layers import MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
import os
os.chdir('/content/drive/My Drive/Mineria/Interna/datos')

datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_R_val_int.npz') ; x_test = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_R_train.npz') ; x_train = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_R_val_int.npz') ; y_test = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_R_train.npz') ; y_train = datos['arr_0']

datos= load('/content/drive/My Drive/Mineria/Interna/datos/y_R_val_ext.npz') ; y_test2 = datos['arr_0']
datos= load('/content/drive/My Drive/Mineria/Interna/datos/X_R_val_ext.npz') ; x_test2 = datos['arr_0']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
print('x_test =',x_test.shape)
print('x_train =',x_train.shape)
print('y_test =',y_test.shape)
print('y_train =',y_train.shape)

print('y_test_ext=', y_test2.shape)
print('x_test_ext=', x_test2.shape)
# Out:
# x_test = (1719, 200, 200, 3)
# x_train = (6874, 200, 200, 3)
# y_test = (1719, 5)
# y_train = (6874, 5)
# y_test_ext= (2063, 5)
# x_test_ext= (2063, 200, 200, 3)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os

# %%
batch_size = 32 # orig paper trained all networks with batch_size=128
epochs = 85

data_augmentation = True
num_classes = 5
# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter para sexo c: 
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 2

# computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
model_type
# Out:
# 'ResNet20v2'

# %%
# input image dimensions.
input_shape = x_train.shape[1:]

#x_train = x_train.astype('float32') 
#x_test = x_test.astype('float32') 

# if subtract pixel mean is enabled 
# center the column-data around zero
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (6874, 200, 200, 3)
# 6874 train samples
# 1719 test samples
# y_train shape: (6874, 5)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 dropout=0.2,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
            x = Dropout(dropout)(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
            x = Dropout(dropout)(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=5, dropout=0.2):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)
    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out
# add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout)(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 200, 200, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 200, 200, 16) 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 200, 16) 272         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 200, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 200, 16) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 200, 200, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 200, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200, 200, 16) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 200, 200, 64) 1088        activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 200, 200, 64) 1088        activation_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 200, 64) 0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 200, 200, 64) 256         add[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 200, 200, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200, 200, 64) 0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 200, 200, 16) 1040        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 200, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200, 200, 16) 0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 200, 200, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 200, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 200, 200, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200, 200, 16) 0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 200, 200, 64) 1088        activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200, 200, 64) 0           add[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 200, 64) 256         add_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 200, 200, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200, 200, 64) 0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 100, 100, 64) 4160        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 100, 100, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 100, 100, 64) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100, 100, 64) 0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 100, 100, 64) 36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 100, 64) 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 100, 100, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100, 100, 64) 0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 100, 100, 128 8320        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 100, 100, 128 8320        activation_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 100, 128 0           conv2d_11[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 100, 100, 128 512         add_2[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 100, 100, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100, 100, 128 0           dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 100, 64) 8256        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 100, 100, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 100, 100, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100, 100, 64) 0           dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 100, 100, 64) 36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 100, 100, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 100, 100, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100, 100, 64) 0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 100, 100, 128 8320        activation_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 100, 128 0           add_2[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 100, 100, 128 512         add_3[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 100, 100, 128 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100, 100, 128 0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 128)  16512       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 128)  0           dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 50, 50, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 50, 50, 128)  0           dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 256)  33024       add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 256)  33024       activation_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 256)  0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 50, 50, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 50, 256)  0           dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 128)  32896       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 50, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 50, 50, 128)  0           dropout_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 50, 50, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 50, 50, 128)  0           dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 256)  33024       activation_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 50, 50, 256)  0           add_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 50, 50, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 50, 50, 256)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 6, 6, 256)    0           dropout_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            46085       flatten[0][0]
# ==================================================================================================
# Total params: 617,605
# Trainable params: 614,117
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2

# %%
# prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), './Modelos')
model_name = 'Raza_0.1_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # fit the model on the batches generated by datagen.flow().
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, 
                        steps_per_epoch=len(x_train)//batch_size,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/85
# 214/214 [==============================] - ETA: 0s - loss: 1.8336 - accuracy: 0.4724
# Epoch 00001: val_accuracy improved from -inf to 0.55497, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.001.h5
# 214/214 [==============================] - 235s 1s/step - loss: 1.8336 - accuracy: 0.4724 - val_loss: 1.5502 - val_accuracy: 0.5550 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/85
# 214/214 [==============================] - ETA: 0s - loss: 1.5709 - accuracy: 0.5526
# Epoch 00002: val_accuracy improved from 0.55497 to 0.58697, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.002.h5
# 214/214 [==============================] - 235s 1s/step - loss: 1.5709 - accuracy: 0.5526 - val_loss: 1.4735 - val_accuracy: 0.5870 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/85
# 214/214 [==============================] - ETA: 0s - loss: 1.4555 - accuracy: 0.5734
# Epoch 00003: val_accuracy improved from 0.58697 to 0.63991, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.003.h5
# 214/214 [==============================] - 235s 1s/step - loss: 1.4555 - accuracy: 0.5734 - val_loss: 1.2727 - val_accuracy: 0.6399 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/85
# 214/214 [==============================] - ETA: 0s - loss: 1.3888 - accuracy: 0.5896
# Epoch 00004: val_accuracy did not improve from 0.63991
# 214/214 [==============================] - 234s 1s/step - loss: 1.3888 - accuracy: 0.5896 - val_loss: 1.2308 - val_accuracy: 0.6393 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/85
# 214/214 [==============================] - ETA: 0s - loss: 1.3398 - accuracy: 0.5827
# Epoch 00005: val_accuracy did not improve from 0.63991
# 214/214 [==============================] - 234s 1s/step - loss: 1.3398 - accuracy: 0.5827 - val_loss: 1.2065 - val_accuracy: 0.6184 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/85
# 214/214 [==============================] - ETA: 0s - loss: 1.2834 - accuracy: 0.6003
# Epoch 00006: val_accuracy improved from 0.63991 to 0.67481, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.006.h5
# 214/214 [==============================] - 234s 1s/step - loss: 1.2834 - accuracy: 0.6003 - val_loss: 1.1175 - val_accuracy: 0.6748 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/85
# 214/214 [==============================] - ETA: 0s - loss: 1.2542 - accuracy: 0.6008
# Epoch 00007: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 234s 1s/step - loss: 1.2542 - accuracy: 0.6008 - val_loss: 1.1060 - val_accuracy: 0.6638 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/85
# 214/214 [==============================] - ETA: 0s - loss: 1.2282 - accuracy: 0.6013
# Epoch 00008: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 234s 1s/step - loss: 1.2282 - accuracy: 0.6013 - val_loss: 1.1239 - val_accuracy: 0.6405 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/85
# 214/214 [==============================] - ETA: 0s - loss: 1.2103 - accuracy: 0.6068
# Epoch 00009: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 234s 1s/step - loss: 1.2103 - accuracy: 0.6068 - val_loss: 1.0676 - val_accuracy: 0.6638 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1885 - accuracy: 0.6087
# Epoch 00010: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 234s 1s/step - loss: 1.1885 - accuracy: 0.6087 - val_loss: 1.0846 - val_accuracy: 0.6510 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1684 - accuracy: 0.6102
# Epoch 00011: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 234s 1s/step - loss: 1.1684 - accuracy: 0.6102 - val_loss: 1.0746 - val_accuracy: 0.6585 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1636 - accuracy: 0.6089
# Epoch 00012: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 233s 1s/step - loss: 1.1636 - accuracy: 0.6089 - val_loss: 1.0258 - val_accuracy: 0.6608 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1519 - accuracy: 0.6092
# Epoch 00013: val_accuracy did not improve from 0.67481
# 214/214 [==============================] - 234s 1s/step - loss: 1.1519 - accuracy: 0.6092 - val_loss: 1.0352 - val_accuracy: 0.6591 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1395 - accuracy: 0.6150
# Epoch 00014: val_accuracy improved from 0.67481 to 0.68121, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.014.h5
# 214/214 [==============================] - 234s 1s/step - loss: 1.1395 - accuracy: 0.6150 - val_loss: 1.0061 - val_accuracy: 0.6812 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1161 - accuracy: 0.6175
# Epoch 00015: val_accuracy did not improve from 0.68121
# 214/214 [==============================] - 233s 1s/step - loss: 1.1161 - accuracy: 0.6175 - val_loss: 1.0032 - val_accuracy: 0.6649 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1199 - accuracy: 0.6155
# Epoch 00016: val_accuracy improved from 0.68121 to 0.68179, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.016.h5
# 214/214 [==============================] - 234s 1s/step - loss: 1.1199 - accuracy: 0.6155 - val_loss: 0.9766 - val_accuracy: 0.6818 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/85
# 214/214 [==============================] - ETA: 0s - loss: 1.1079 - accuracy: 0.6162
# Epoch 00017: val_accuracy did not improve from 0.68179
# 214/214 [==============================] - 234s 1s/step - loss: 1.1079 - accuracy: 0.6162 - val_loss: 0.9874 - val_accuracy: 0.6812 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0986 - accuracy: 0.6220
# Epoch 00018: val_accuracy did not improve from 0.68179
# 214/214 [==============================] - 233s 1s/step - loss: 1.0986 - accuracy: 0.6220 - val_loss: 0.9873 - val_accuracy: 0.6702 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0839 - accuracy: 0.6288
# Epoch 00019: val_accuracy did not improve from 0.68179
# 214/214 [==============================] - 234s 1s/step - loss: 1.0839 - accuracy: 0.6288 - val_loss: 0.9961 - val_accuracy: 0.6684 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0722 - accuracy: 0.6285
# Epoch 00020: val_accuracy improved from 0.68179 to 0.68296, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.020.h5
# 214/214 [==============================] - 234s 1s/step - loss: 1.0722 - accuracy: 0.6285 - val_loss: 0.9586 - val_accuracy: 0.6830 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0763 - accuracy: 0.6270
# Epoch 00021: val_accuracy did not improve from 0.68296
# 214/214 [==============================] - 233s 1s/step - loss: 1.0763 - accuracy: 0.6270 - val_loss: 0.9714 - val_accuracy: 0.6661 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0575 - accuracy: 0.6356
# Epoch 00022: val_accuracy did not improve from 0.68296
# 214/214 [==============================] - 234s 1s/step - loss: 1.0575 - accuracy: 0.6356 - val_loss: 0.9741 - val_accuracy: 0.6702 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0576 - accuracy: 0.6326
# Epoch 00023: val_accuracy did not improve from 0.68296
# 214/214 [==============================] - 234s 1s/step - loss: 1.0576 - accuracy: 0.6326 - val_loss: 0.9792 - val_accuracy: 0.6760 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0488 - accuracy: 0.6381
# Epoch 00024: val_accuracy improved from 0.68296 to 0.70622, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.024.h5
# 214/214 [==============================] - 235s 1s/step - loss: 1.0488 - accuracy: 0.6381 - val_loss: 0.9162 - val_accuracy: 0.7062 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0270 - accuracy: 0.6530
# Epoch 00025: val_accuracy did not improve from 0.70622
# 214/214 [==============================] - 233s 1s/step - loss: 1.0270 - accuracy: 0.6530 - val_loss: 0.9327 - val_accuracy: 0.6824 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0260 - accuracy: 0.6540
# Epoch 00026: val_accuracy did not improve from 0.70622
# 214/214 [==============================] - 233s 1s/step - loss: 1.0260 - accuracy: 0.6540 - val_loss: 0.8940 - val_accuracy: 0.6992 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0134 - accuracy: 0.6517
# Epoch 00027: val_accuracy did not improve from 0.70622
# 214/214 [==============================] - 233s 1s/step - loss: 1.0134 - accuracy: 0.6517 - val_loss: 0.9152 - val_accuracy: 0.6992 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/85
# 214/214 [==============================] - ETA: 0s - loss: 1.0172 - accuracy: 0.6529
# Epoch 00028: val_accuracy did not improve from 0.70622
# 214/214 [==============================] - 233s 1s/step - loss: 1.0172 - accuracy: 0.6529 - val_loss: 0.9204 - val_accuracy: 0.6911 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9968 - accuracy: 0.6663
# Epoch 00029: val_accuracy did not improve from 0.70622
# 214/214 [==============================] - 233s 1s/step - loss: 0.9968 - accuracy: 0.6663 - val_loss: 0.9201 - val_accuracy: 0.6946 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9891 - accuracy: 0.6606
# Epoch 00030: val_accuracy did not improve from 0.70622
# 214/214 [==============================] - 234s 1s/step - loss: 0.9891 - accuracy: 0.6606 - val_loss: 0.8926 - val_accuracy: 0.7062 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9834 - accuracy: 0.6593
# Epoch 00031: val_accuracy improved from 0.70622 to 0.71030, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.031.h5
# 214/214 [==============================] - 234s 1s/step - loss: 0.9834 - accuracy: 0.6593 - val_loss: 0.8749 - val_accuracy: 0.7103 - lr: 0.0010
# Learning rate:  0.001
# Epoch 32/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9878 - accuracy: 0.6630
# Epoch 00032: val_accuracy did not improve from 0.71030
# 214/214 [==============================] - 233s 1s/step - loss: 0.9878 - accuracy: 0.6630 - val_loss: 0.8778 - val_accuracy: 0.6998 - lr: 0.0010
# Learning rate:  0.001
# Epoch 33/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9825 - accuracy: 0.6706
# Epoch 00033: val_accuracy did not improve from 0.71030
# 214/214 [==============================] - 233s 1s/step - loss: 0.9825 - accuracy: 0.6706 - val_loss: 0.8662 - val_accuracy: 0.7091 - lr: 0.0010
# Learning rate:  0.001
# Epoch 34/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9641 - accuracy: 0.6723
# Epoch 00034: val_accuracy did not improve from 0.71030
# 214/214 [==============================] - 233s 1s/step - loss: 0.9641 - accuracy: 0.6723 - val_loss: 0.9213 - val_accuracy: 0.7039 - lr: 0.0010
# Learning rate:  0.001
# Epoch 35/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9683 - accuracy: 0.6697
# Epoch 00035: val_accuracy improved from 0.71030 to 0.72077, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.035.h5
# 214/214 [==============================] - 234s 1s/step - loss: 0.9683 - accuracy: 0.6697 - val_loss: 0.8662 - val_accuracy: 0.7208 - lr: 0.0010
# Learning rate:  0.001
# Epoch 36/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9553 - accuracy: 0.6719
# Epoch 00036: val_accuracy did not improve from 0.72077
# 214/214 [==============================] - 233s 1s/step - loss: 0.9553 - accuracy: 0.6719 - val_loss: 0.9565 - val_accuracy: 0.6806 - lr: 0.0010
# Learning rate:  0.001
# Epoch 37/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9538 - accuracy: 0.6751
# Epoch 00037: val_accuracy did not improve from 0.72077
# 214/214 [==============================] - 233s 1s/step - loss: 0.9538 - accuracy: 0.6751 - val_loss: 0.8288 - val_accuracy: 0.7208 - lr: 0.0010
# Learning rate:  0.001
# Epoch 38/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9401 - accuracy: 0.6846
# Epoch 00038: val_accuracy did not improve from 0.72077
# 214/214 [==============================] - 233s 1s/step - loss: 0.9401 - accuracy: 0.6846 - val_loss: 0.8707 - val_accuracy: 0.7144 - lr: 0.0010
# Learning rate:  0.001
# Epoch 39/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9308 - accuracy: 0.6811
# Epoch 00039: val_accuracy did not improve from 0.72077
# 214/214 [==============================] - 233s 1s/step - loss: 0.9308 - accuracy: 0.6811 - val_loss: 0.8883 - val_accuracy: 0.7027 - lr: 0.0010
# Learning rate:  0.001
# Epoch 40/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9276 - accuracy: 0.6896
# Epoch 00040: val_accuracy did not improve from 0.72077
# 214/214 [==============================] - 233s 1s/step - loss: 0.9276 - accuracy: 0.6896 - val_loss: 0.8932 - val_accuracy: 0.7056 - lr: 0.0010
# Learning rate:  0.001
# Epoch 41/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9197 - accuracy: 0.6885
# Epoch 00041: val_accuracy improved from 0.72077 to 0.73357, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.041.h5
# 214/214 [==============================] - 234s 1s/step - loss: 0.9197 - accuracy: 0.6885 - val_loss: 0.8352 - val_accuracy: 0.7336 - lr: 0.0010
# Learning rate:  0.001
# Epoch 42/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9084 - accuracy: 0.6995
# Epoch 00042: val_accuracy did not improve from 0.73357
# 214/214 [==============================] - 233s 1s/step - loss: 0.9084 - accuracy: 0.6995 - val_loss: 0.9034 - val_accuracy: 0.7080 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 43/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9012 - accuracy: 0.6960
# Epoch 00043: val_accuracy did not improve from 0.73357
# 214/214 [==============================] - 233s 1s/step - loss: 0.9012 - accuracy: 0.6960 - val_loss: 0.8347 - val_accuracy: 0.7318 - lr: 0.0010
# Learning rate:  0.001
# Epoch 44/85
# 214/214 [==============================] - ETA: 0s - loss: 0.9021 - accuracy: 0.6948
# Epoch 00044: val_accuracy improved from 0.73357 to 0.73764, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.044.h5
# 214/214 [==============================] - 234s 1s/step - loss: 0.9021 - accuracy: 0.6948 - val_loss: 0.8372 - val_accuracy: 0.7376 - lr: 0.0010
# Learning rate:  0.001
# Epoch 45/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8900 - accuracy: 0.6958
# Epoch 00045: val_accuracy did not improve from 0.73764
# 214/214 [==============================] - 233s 1s/step - loss: 0.8900 - accuracy: 0.6958 - val_loss: 0.8376 - val_accuracy: 0.7213 - lr: 0.0010
# Learning rate:  0.001
# Epoch 46/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8917 - accuracy: 0.7026
# Epoch 00046: val_accuracy did not improve from 0.73764
# 214/214 [==============================] - 233s 1s/step - loss: 0.8917 - accuracy: 0.7026 - val_loss: 0.8336 - val_accuracy: 0.7359 - lr: 0.0010
# Learning rate:  0.001
# Epoch 47/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8738 - accuracy: 0.7084
# Epoch 00047: val_accuracy did not improve from 0.73764
# 214/214 [==============================] - 233s 1s/step - loss: 0.8738 - accuracy: 0.7084 - val_loss: 0.8412 - val_accuracy: 0.7289 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 48/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8771 - accuracy: 0.7056
# Epoch 00048: val_accuracy improved from 0.73764 to 0.74985, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.048.h5
# 214/214 [==============================] - 233s 1s/step - loss: 0.8771 - accuracy: 0.7056 - val_loss: 0.7872 - val_accuracy: 0.7499 - lr: 0.0010
# Learning rate:  0.001
# Epoch 49/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8643 - accuracy: 0.7119
# Epoch 00049: val_accuracy did not improve from 0.74985
# 214/214 [==============================] - 233s 1s/step - loss: 0.8643 - accuracy: 0.7119 - val_loss: 0.8109 - val_accuracy: 0.7341 - lr: 0.0010
# Learning rate:  0.001
# Epoch 50/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8682 - accuracy: 0.7121
# Epoch 00050: val_accuracy improved from 0.74985 to 0.75393, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.050.h5
# 214/214 [==============================] - 233s 1s/step - loss: 0.8682 - accuracy: 0.7121 - val_loss: 0.7853 - val_accuracy: 0.7539 - lr: 0.0010
# Learning rate:  0.001
# Epoch 51/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8556 - accuracy: 0.7166
# Epoch 00051: val_accuracy did not improve from 0.75393
# 214/214 [==============================] - 233s 1s/step - loss: 0.8556 - accuracy: 0.7166 - val_loss: 0.7801 - val_accuracy: 0.7458 - lr: 0.0010
# Learning rate:  0.001
# Epoch 52/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8572 - accuracy: 0.7138
# Epoch 00052: val_accuracy did not improve from 0.75393
# 214/214 [==============================] - 232s 1s/step - loss: 0.8572 - accuracy: 0.7138 - val_loss: 0.7922 - val_accuracy: 0.7504 - lr: 0.0010
# Learning rate:  0.001
# Epoch 53/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8369 - accuracy: 0.7200
# Epoch 00053: val_accuracy did not improve from 0.75393
# 214/214 [==============================] - 232s 1s/step - loss: 0.8369 - accuracy: 0.7200 - val_loss: 0.9534 - val_accuracy: 0.6911 - lr: 0.0010
# Learning rate:  0.001
# Epoch 54/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8391 - accuracy: 0.7233
# Epoch 00054: val_accuracy did not improve from 0.75393
# 214/214 [==============================] - 232s 1s/step - loss: 0.8391 - accuracy: 0.7233 - val_loss: 0.8374 - val_accuracy: 0.7254 - lr: 0.0010
# Learning rate:  0.001
# Epoch 55/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8275 - accuracy: 0.7220
# Epoch 00055: val_accuracy improved from 0.75393 to 0.75684, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.055.h5
# 214/214 [==============================] - 233s 1s/step - loss: 0.8275 - accuracy: 0.7220 - val_loss: 0.7693 - val_accuracy: 0.7568 - lr: 0.0010
# Learning rate:  0.001
# Epoch 56/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8287 - accuracy: 0.7283
# Epoch 00056: val_accuracy did not improve from 0.75684
# 214/214 [==============================] - 232s 1s/step - loss: 0.8287 - accuracy: 0.7283 - val_loss: 0.7766 - val_accuracy: 0.7504 - lr: 0.0010
# Learning rate:  0.001
# Epoch 57/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8206 - accuracy: 0.7308
# Epoch 00057: val_accuracy improved from 0.75684 to 0.76207, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.057.h5
# 214/214 [==============================] - 233s 1s/step - loss: 0.8206 - accuracy: 0.7308 - val_loss: 0.7746 - val_accuracy: 0.7621 - lr: 0.0010
# Learning rate:  0.001
# Epoch 58/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8143 - accuracy: 0.7321
# Epoch 00058: val_accuracy did not improve from 0.76207
# 214/214 [==============================] - 232s 1s/step - loss: 0.8143 - accuracy: 0.7321 - val_loss: 0.8741 - val_accuracy: 0.7295 - lr: 0.0010
# Learning rate:  0.001
# Epoch 59/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8065 - accuracy: 0.7330
# Epoch 00059: val_accuracy did not improve from 0.76207
# 214/214 [==============================] - 232s 1s/step - loss: 0.8065 - accuracy: 0.7330 - val_loss: 0.8503 - val_accuracy: 0.7330 - lr: 0.0010
# Learning rate:  0.001
# Epoch 60/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8030 - accuracy: 0.7334
# Epoch 00060: val_accuracy did not improve from 0.76207
# 214/214 [==============================] - 232s 1s/step - loss: 0.8030 - accuracy: 0.7334 - val_loss: 0.7945 - val_accuracy: 0.7563 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 61/85
# 214/214 [==============================] - ETA: 0s - loss: 0.8054 - accuracy: 0.7375
# Epoch 00061: val_accuracy did not improve from 0.76207
# 214/214 [==============================] - 232s 1s/step - loss: 0.8054 - accuracy: 0.7375 - val_loss: 0.7995 - val_accuracy: 0.7522 - lr: 0.0010
# Learning rate:  0.001
# Epoch 62/85
# 214/214 [==============================] - ETA: 0s - loss: 0.7882 - accuracy: 0.7431
# Epoch 00062: val_accuracy improved from 0.76207 to 0.76498, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.062.h5
# 214/214 [==============================] - 233s 1s/step - loss: 0.7882 - accuracy: 0.7431 - val_loss: 0.7563 - val_accuracy: 0.7650 - lr: 0.0010
# Learning rate:  0.001
# Epoch 63/85
# 214/214 [==============================] - ETA: 0s - loss: 0.7911 - accuracy: 0.7412
# Epoch 00063: val_accuracy did not improve from 0.76498
# 214/214 [==============================] - 232s 1s/step - loss: 0.7911 - accuracy: 0.7412 - val_loss: 0.8275 - val_accuracy: 0.7388 - lr: 0.0010
# Learning rate:  0.001
# Epoch 64/85
# 214/214 [==============================] - ETA: 0s - loss: 0.7759 - accuracy: 0.7512
# Epoch 00064: val_accuracy did not improve from 0.76498
# 214/214 [==============================] - 232s 1s/step - loss: 0.7759 - accuracy: 0.7512 - val_loss: 0.7541 - val_accuracy: 0.7609 - lr: 0.0010
# Learning rate:  0.001
# Epoch 65/85
# 214/214 [==============================] - ETA: 0s - loss: 0.7799 - accuracy: 0.7469
# Epoch 00065: val_accuracy improved from 0.76498 to 0.76672, saving model to /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.065.h5
# 214/214 [==============================] - 233s 1s/step - loss: 0.7799 - accuracy: 0.7469 - val_loss: 0.7500 - val_accuracy: 0.7667 - lr: 0.0010
# Learning rate:  0.001
# Epoch 66/85
# 214/214 [==============================] - ETA: 0s - loss: 0.7758 - accuracy: 0.7420
# Epoch 00066: val_accuracy did not improve from 0.76672
# 214/214 [==============================] - 232s 1s/step - loss: 0.7758 - accuracy: 0.7420 - val_loss: 0.7606 - val_accuracy: 0.7615 - lr: 0.0010
# Learning rate:  0.001
# Epoch 67/85
# 126/214 [================>.............] - ETA: 1:29 - loss: 0.7567 - accuracy: 0.7572

# %%
#using last check point
from tensorflow.keras.models import load_model

model = load_model('/content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.065.h')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-16-0bd06b131591> in <module>()
#       2 from tensorflow.keras.models import load_model
#       3
# ----> 4 model = load_model('/content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.065.h')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     187       filepath = str(filepath)
#     188     if isinstance(filepath, six.string_types):
# --> 189       loader_impl.parse_saved_model(filepath)
#     190       return saved_model_load.load(filepath, compile)
#     191
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 113                    constants.SAVED_MODEL_FILENAME_PB))
#     114
#     115
#
# OSError: SavedModel file does not exist at: /content/drive/.shortcut-targets-by-id/1EIw6ZmKwlGHMh1CQuZhn85QTdh7-YF5_/Interna/datos/./Modelos/Raza_0.1_ResNet20v2_model.065.h/{saved_model.pbtxt|saved_model.pb}

# %%
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
