# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from os import remove
from skimage.color import rgb2gray
from numpy import load
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from sklearn.model_selection import train_test_split
from google.colab import files
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape,ZeroPadding2D,Activation,MaxPooling2D,Dropout
from keras.layers import BatchNormalization
from keras.models import Model
from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SpatialDropout2D
from matplotlib import pyplot as plt
import keras
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D
from tensorflow.keras.layers import MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
import os
os.chdir('/content/drive/My Drive/Minería de Datos/Interna/datos')

datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/X_E_val_int.npz') ; x_test = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/X_E_train.npz') ; x_train = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/y_E_val_int.npz') ; y_test = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Interna/datos/y_E_train.npz') ; y_train = datos['arr_0']

# %%
print('x_test =',x_test.shape)
print('x_train =',x_train.shape)
print('y_test =',y_test.shape)
print('y_train =',y_train.shape)
# Out:
# x_test = (1719, 200, 200, 3)
# x_train = (6874, 200, 200, 3)
# y_test = (1719, 101)
# y_train = (6874, 101)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input
from tensorflow.keras.layers import Flatten, add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import numpy as np
import os

# %%
batch_size = 32 # orig paper trained all networks with batch_size=128
epochs = 100
#epochs = 10
data_augmentation = True
num_classes = 101
# subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# Model parameter para sexo c: 
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 2

# model version
# orig paper: version = 1 (ResNet v1), 
# improved ResNet: version = 2 (ResNet v2)
version = 2

# computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)
model_type
# Out:
# 'ResNet20v2'

# %%
# input image dimensions.
input_shape = x_train.shape[1:]

#x_train = x_train.astype('float32') 
#x_test = x_test.astype('float32') 

# if subtract pixel mean is enabled 
# center the column-data around zero
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (6874, 200, 200, 3)
# 6874 train samples
# 1719 test samples
# y_train shape: (6874, 101)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    Arguments:
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    Returns:
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))
    
    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=101):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or 
    also known as bottleneck layer.
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, 
    the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, 
    while the number of filter maps is
    doubled. Within each stage, the layers have 
    the same number filters and the same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    Arguments:
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    Returns:
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 110 in [b])')
    # start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)
    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU
    # on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                # first layer and first stage
                if res_block == 0:  
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                # first layer but not first stage
                if res_block == 0:
                    # downsample
                    strides = 2 

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection
                # to match changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = add([x, y])

        num_filters_in = num_filters_out
# add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
plot_model(model, to_file="%s.png" % model_type, show_shapes=True)
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 200, 200, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 200, 16) 272         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 200, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 200, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 200, 200, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 200, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200, 200, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 200, 200, 64) 1088        activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 200, 200, 64) 1088        activation_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 200, 64) 0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 200, 200, 64) 256         add[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200, 200, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 200, 200, 16) 1040        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 200, 16) 64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200, 200, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 200, 200, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 200, 16) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200, 200, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 200, 200, 64) 1088        activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200, 200, 64) 0           add[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 200, 64) 256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200, 200, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 100, 100, 64) 4160        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 100, 100, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100, 100, 64) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 100, 100, 64) 36928       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 100, 64) 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100, 100, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 100, 100, 128 8320        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 100, 100, 128 8320        activation_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 100, 128 0           conv2d_11[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 100, 100, 128 512         add_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100, 100, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 100, 64) 8256        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 100, 100, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100, 100, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 100, 100, 64) 36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 100, 100, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100, 100, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 100, 100, 128 8320        activation_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 100, 128 0           add_2[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 100, 100, 128 512         add_3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 100, 100, 128 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 128)  16512       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 50, 50, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 50, 50, 128)  147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 50, 50, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 256)  33024       add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 256)  33024       activation_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 256)  0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 256)  1024        add_4[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 50, 50, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 128)  32896       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 50, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 50, 50, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 128)  512         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 50, 50, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 256)  33024       activation_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 50, 50, 256)  0           add_4[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 50, 50, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 6, 6, 256)    0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 101)          930917      flatten[0][0]
# ==================================================================================================
# Total params: 1,502,437
# Trainable params: 1,498,949
# Non-trainable params: 3,488
# __________________________________________________________________________________________________
# ResNet20v2

# %%
#using last check point
#from tensorflow.keras.models import load_model

#model = load_model('/content/drive/My Drive/Minería de Datos/Interna/datos/Modelos/Raza_Primera_ResNet20v2_model.087.h5')

# %%
# prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), './Modelos')
model_name = 'Edad_Primera_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # this will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False)

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # fit the model on the batches generated by datagen.flow().
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, 
                        steps_per_epoch=len(x_train)//batch_size,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/100
# 214/214 [==============================] - ETA: 0s - loss: 4.7284 - accuracy: 0.0941
# Epoch 00001: val_accuracy improved from -inf to 0.09948, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Edad_Primera_ResNet20v2_model.001.h5
# 214/214 [==============================] - 182s 850ms/step - loss: 4.7284 - accuracy: 0.0941 - val_loss: 4.4260 - val_accuracy: 0.0995 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/100
# 214/214 [==============================] - ETA: 0s - loss: 4.2756 - accuracy: 0.1096
# Epoch 00002: val_accuracy improved from 0.09948 to 0.11518, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Edad_Primera_ResNet20v2_model.002.h5
# 214/214 [==============================] - 179s 837ms/step - loss: 4.2756 - accuracy: 0.1096 - val_loss: 4.2651 - val_accuracy: 0.1152 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/100
# 214/214 [==============================] - ETA: 0s - loss: 4.1230 - accuracy: 0.1194
# Epoch 00003: val_accuracy improved from 0.11518 to 0.12100, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Edad_Primera_ResNet20v2_model.003.h5
# 214/214 [==============================] - 177s 825ms/step - loss: 4.1230 - accuracy: 0.1194 - val_loss: 4.1540 - val_accuracy: 0.1210 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/100
# 214/214 [==============================] - ETA: 0s - loss: 3.9902 - accuracy: 0.1215
# Epoch 00004: val_accuracy improved from 0.12100 to 0.12275, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Edad_Primera_ResNet20v2_model.004.h5
# 214/214 [==============================] - 177s 825ms/step - loss: 3.9902 - accuracy: 0.1215 - val_loss: 4.0403 - val_accuracy: 0.1227 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/100
# 214/214 [==============================] - ETA: 0s - loss: 3.8727 - accuracy: 0.1307
# Epoch 00005: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 176s 824ms/step - loss: 3.8727 - accuracy: 0.1307 - val_loss: 4.0769 - val_accuracy: 0.1053 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/100
# 214/214 [==============================] - ETA: 0s - loss: 3.7839 - accuracy: 0.1353
# Epoch 00006: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 176s 823ms/step - loss: 3.7839 - accuracy: 0.1353 - val_loss: 4.0247 - val_accuracy: 0.1216 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/100
# 214/214 [==============================] - ETA: 0s - loss: 3.7092 - accuracy: 0.1441
# Epoch 00007: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 176s 824ms/step - loss: 3.7092 - accuracy: 0.1441 - val_loss: 3.9909 - val_accuracy: 0.1041 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/100
# 214/214 [==============================] - ETA: 0s - loss: 3.6323 - accuracy: 0.1491
# Epoch 00008: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 176s 821ms/step - loss: 3.6323 - accuracy: 0.1491 - val_loss: 3.9488 - val_accuracy: 0.1204 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/100
# 214/214 [==============================] - ETA: 0s - loss: 3.5411 - accuracy: 0.1625
# Epoch 00009: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 175s 818ms/step - loss: 3.5411 - accuracy: 0.1625 - val_loss: 3.9835 - val_accuracy: 0.1082 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/100
# 214/214 [==============================] - ETA: 0s - loss: 3.4881 - accuracy: 0.1676
# Epoch 00010: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 175s 818ms/step - loss: 3.4881 - accuracy: 0.1676 - val_loss: 3.9465 - val_accuracy: 0.1024 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/100
# 214/214 [==============================] - ETA: 0s - loss: 3.4288 - accuracy: 0.1687
# Epoch 00011: val_accuracy did not improve from 0.12275
# 214/214 [==============================] - 175s 817ms/step - loss: 3.4288 - accuracy: 0.1687 - val_loss: 4.0426 - val_accuracy: 0.1204 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/100
# 214/214 [==============================] - ETA: 0s - loss: 3.3589 - accuracy: 0.1798
# Epoch 00012: val_accuracy improved from 0.12275 to 0.12565, saving model to /content/drive/My Drive/Minería de Datos/Interna/datos/./Modelos/Edad_Primera_ResNet20v2_model.012.h5
# 214/214 [==============================] - 176s 821ms/step - loss: 3.3589 - accuracy: 0.1798 - val_loss: 3.9733 - val_accuracy: 0.1257 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/100
#
val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.8545 - accuracy: 0.5152 - val_loss: 5.8193 - val_accuracy: 0.0966 - lr: 0.0010
# Learning rate:  0.001
# Epoch 43/100
# 214/214 [==============================] - ETA: 0s - loss: 1.8236 - accuracy: 0.5284
# Epoch 00043: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.8236 - accuracy: 0.5284 - val_loss: 5.7157 - val_accuracy: 0.1082 - lr: 0.0010
# Learning rate:  0.001
# Epoch 44/100
# 214/214 [==============================] - ETA: 0s - loss: 1.7765 - accuracy: 0.5368
# Epoch 00044: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.7765 - accuracy: 0.5368 - val_loss: 5.7053 - val_accuracy: 0.0937 - lr: 0.0010
# Learning rate:  0.001
# Epoch 45/100
# 214/214 [==============================] - ETA: 0s - loss: 1.7614 - accuracy: 0.5408
# Epoch 00045: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.7614 - accuracy: 0.5408 - val_loss: 5.9039 - val_accuracy: 0.1105 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 46/100
# 214/214 [==============================] - ETA: 0s - loss: 1.7297 - accuracy: 0.5491
# Epoch 00046: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.7297 - accuracy: 0.5491 - val_loss: 5.8202 - val_accuracy: 0.0966 - lr: 0.0010
# Learning rate:  0.001
# Epoch 47/100
# 214/214 [==============================] - ETA: 0s - loss: 1.6846 - accuracy: 0.5598
# Epoch 00047: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.6846 - accuracy: 0.5598 - val_loss: 6.0534 - val_accuracy: 0.1024 - lr: 0.0010
# Learning rate:  0.001
# Epoch 48/100
# 214/214 [==============================] - ETA: 0s - loss: 1.6741 - accuracy: 0.5604
# Epoch 00048: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.6741 - accuracy: 0.5604 - val_loss: 5.7686 - val_accuracy: 0.0977 - lr: 0.0010
# Learning rate:  0.001
# Epoch 49/100
# 214/214 [==============================] - ETA: 0s - loss: 1.6385 - accuracy: 0.5666
# Epoch 00049: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.6385 - accuracy: 0.5666 - val_loss: 6.4783 - val_accuracy: 0.0919 - lr: 0.0010
# Learning rate:  0.001
# Epoch 50/100
# 214/214 [==============================] - ETA: 0s - loss: 1.6351 - accuracy: 0.5753
# Epoch 00050: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.6351 - accuracy: 0.5753 - val_loss: 6.1520 - val_accuracy: 0.0960 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 51/100
# 214/214 [==============================] - ETA: 0s - loss: 1.5751 - accuracy: 0.5892
# Epoch 00051: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.5751 - accuracy: 0.5892 - val_loss: 6.1565 - val_accuracy: 0.1006 - lr: 0.0010
# Learning rate:  0.001
# Epoch 52/100
# 214/214 [==============================] - ETA: 0s - loss: 1.5582 - accuracy: 0.5946
# Epoch 00052: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.5582 - accuracy: 0.5946 - val_loss: 6.4139 - val_accuracy: 0.0884 - lr: 0.0010
# Learning rate:  0.001
# Epoch 53/100
# 214/214 [==============================] - ETA: 0s - loss: 1.5345 - accuracy: 0.5956
# Epoch 00053: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.5345 - accuracy: 0.5956 - val_loss: 6.6124 - val_accuracy: 0.0913 - lr: 0.0010
# Learning rate:  0.001
# Epoch 54/100
# 214/214 [==============================] - ETA: 0s - loss: 1.5406 - accuracy: 0.5979
# Epoch 00054: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.5406 - accuracy: 0.5979 - val_loss: 6.4957 - val_accuracy: 0.0995 - lr: 0.0010
# Learning rate:  0.001
# Epoch 55/100
# 214/214 [==============================] - ETA: 0s - loss: 1.4961 - accuracy: 0.6155
# Epoch 00055: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.4961 - accuracy: 0.6155 - val_loss: 6.7479 - val_accuracy: 0.0925 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 56/100
# 214/214 [==============================] - ETA: 0s - loss: 1.4929 - accuracy: 0.6074
# Epoch 00056: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 817ms/step - loss: 1.4929 - accuracy: 0.6074 - val_loss: 6.5752 - val_accuracy: 0.0902 - lr: 0.0010
# Learning rate:  0.001
# Epoch 57/100
# 214/214 [==============================] - ETA: 0s - loss: 1.4332 - accuracy: 0.6244
# Epoch 00057: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 817ms/step - loss: 1.4332 - accuracy: 0.6244 - val_loss: 6.5860 - val_accuracy: 0.1006 - lr: 0.0010
# Learning rate:  0.001
# Epoch 58/100
# 214/214 [==============================] - ETA: 0s - loss: 1.4151 - accuracy: 0.6299
# Epoch 00058: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 820ms/step - loss: 1.4151 - accuracy: 0.6299 - val_loss: 6.5874 - val_accuracy: 0.0913 - lr: 0.0010
# Learning rate:  0.001
# Epoch 59/100
# 214/214 [==============================] - ETA: 0s - loss: 1.4168 - accuracy: 0.6381
# Epoch 00059: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 817ms/step - loss: 1.4168 - accuracy: 0.6381 - val_loss: 6.8324 - val_accuracy: 0.0942 - lr: 0.0010
# Learning rate:  0.001
# Epoch 60/100
# 214/214 [==============================] - ETA: 0s - loss: 1.3949 - accuracy: 0.6381
# Epoch 00060: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.3949 - accuracy: 0.6381 - val_loss: 6.6817 - val_accuracy: 0.0902 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 61/100
# 214/214 [==============================] - ETA: 0s - loss: 1.3854 - accuracy: 0.6391
# Epoch 00061: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.3854 - accuracy: 0.6391 - val_loss: 6.9656 - val_accuracy: 0.0902 - lr: 0.0010
# Learning rate:  0.001
# Epoch 62/100
# 214/214 [==============================] - ETA: 0s - loss: 1.3734 - accuracy: 0.6464
# Epoch 00062: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 176s 820ms/step - loss: 1.3734 - accuracy: 0.6464 - val_loss: 7.0903 - val_accuracy: 0.0832 - lr: 0.0010
# Learning rate:  0.001
# Epoch 63/100
# 214/214 [==============================] - ETA: 0s - loss: 1.3294 - accuracy: 0.6495
# Epoch 00063: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.3294 - accuracy: 0.6495 - val_loss: 6.9856 - val_accuracy: 0.0995 - lr: 0.0010
# Learning rate:  0.001
# Epoch 64/100
# 214/214 [==============================] - ETA: 0s - loss: 1.3198 - accuracy: 0.6614
# Epoch 00064: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.3198 - accuracy: 0.6614 - val_loss: 7.0125 - val_accuracy: 0.0890 - lr: 0.0010
# Learning rate:  0.001
# Epoch 65/100
# 214/214 [==============================] - ETA: 0s - loss: 1.3012 - accuracy: 0.6654
# Epoch 00065: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.3012 - accuracy: 0.6654 - val_loss: 7.0003 - val_accuracy: 0.0844 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 66/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2928 - accuracy: 0.6630
# Epoch 00066: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.2928 - accuracy: 0.6630 - val_loss: 7.4265 - val_accuracy: 0.0989 - lr: 0.0010
# Learning rate:  0.001
# Epoch 67/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2795 - accuracy: 0.6656
# Epoch 00067: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.2795 - accuracy: 0.6656 - val_loss: 7.1635 - val_accuracy: 0.1024 - lr: 0.0010
# Learning rate:  0.001
# Epoch 68/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2547 - accuracy: 0.6789
# Epoch 00068: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.2547 - accuracy: 0.6789 - val_loss: 7.2852 - val_accuracy: 0.1012 - lr: 0.0010
# Learning rate:  0.001
# Epoch 69/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2649 - accuracy: 0.6768
# Epoch 00069: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.2649 - accuracy: 0.6768 - val_loss: 7.7757 - val_accuracy: 0.0716 - lr: 0.0010
# Learning rate:  0.001
# Epoch 70/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2473 - accuracy: 0.6795
# Epoch 00070: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 820ms/step - loss: 1.2473 - accuracy: 0.6795 - val_loss: 7.0266 - val_accuracy: 0.0902 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 71/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2226 - accuracy: 0.6888
# Epoch 00071: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 817ms/step - loss: 1.2226 - accuracy: 0.6888 - val_loss: 7.2511 - val_accuracy: 0.0855 - lr: 0.0010
# Learning rate:  0.001
# Epoch 72/100
# 214/214 [==============================] - ETA: 0s - loss: 1.2266 - accuracy: 0.6850
# Epoch 00072: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.2266 - accuracy: 0.6850 - val_loss: 7.4888 - val_accuracy: 0.0931 - lr: 0.0010
# Learning rate:  0.001
# Epoch 73/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1879 - accuracy: 0.6956
# Epoch 00073: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.1879 - accuracy: 0.6956 - val_loss: 7.3586 - val_accuracy: 0.1001 - lr: 0.0010
# Learning rate:  0.001
# Epoch 74/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1663 - accuracy: 0.7018
# Epoch 00074: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.1663 - accuracy: 0.7018 - val_loss: 7.5070 - val_accuracy: 0.0878 - lr: 0.0010
# Learning rate:  0.001
# Epoch 75/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1703 - accuracy: 0.7034
# Epoch 00075: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.1703 - accuracy: 0.7034 - val_loss: 7.5183 - val_accuracy: 0.0908 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 76/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1641 - accuracy: 0.7017
# Epoch 00076: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.1641 - accuracy: 0.7017 - val_loss: 7.7387 - val_accuracy: 0.0937 - lr: 0.0010
# Learning rate:  0.001
# Epoch 77/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1207 - accuracy: 0.7121
# Epoch 00077: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.1207 - accuracy: 0.7121 - val_loss: 7.5071 - val_accuracy: 0.1001 - lr: 0.0010
# Learning rate:  0.001
# Epoch 78/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1244 - accuracy: 0.7169
# Epoch 00078: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 1.1244 - accuracy: 0.7169 - val_loss: 7.5410 - val_accuracy: 0.0942 - lr: 0.0010
# Learning rate:  0.001
# Epoch 79/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1254 - accuracy: 0.7179
# Epoch 00079: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.1254 - accuracy: 0.7179 - val_loss: 7.5569 - val_accuracy: 0.0890 - lr: 0.0010
# Learning rate:  0.001
# Epoch 80/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1049 - accuracy: 0.7176
# Epoch 00080: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.1049 - accuracy: 0.7176 - val_loss: 7.6334 - val_accuracy: 0.0960 - lr: 3.1623e-04
# Learning rate:  0.001
# Epoch 81/100
# 214/214 [==============================] - ETA: 0s - loss: 1.1162 - accuracy: 0.7205
# Epoch 00081: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 1.1162 - accuracy: 0.7205 - val_loss: 7.6692 - val_accuracy: 0.0966 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 82/100
# 214/214 [==============================] - ETA: 0s - loss: 0.9320 - accuracy: 0.7825
# Epoch 00082: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 820ms/step - loss: 0.9320 - accuracy: 0.7825 - val_loss: 7.7113 - val_accuracy: 0.0925 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 83/100
# 214/214 [==============================] - ETA: 0s - loss: 0.8390 - accuracy: 0.8120
# Epoch 00083: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 820ms/step - loss: 0.8390 - accuracy: 0.8120 - val_loss: 8.0220 - val_accuracy: 0.0948 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 84/100
# 214/214 [==============================] - ETA: 0s - loss: 0.8284 - accuracy: 0.8101
# Epoch 00084: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 817ms/step - loss: 0.8284 - accuracy: 0.8101 - val_loss: 8.2641 - val_accuracy: 0.0896 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 85/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7875 - accuracy: 0.8191
# Epoch 00085: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7875 - accuracy: 0.8191 - val_loss: 8.4383 - val_accuracy: 0.0902 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 86/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7711 - accuracy: 0.8224
# Epoch 00086: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 0.7711 - accuracy: 0.8224 - val_loss: 8.6279 - val_accuracy: 0.0948 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 87/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7760 - accuracy: 0.8218
# Epoch 00087: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 0.7760 - accuracy: 0.8218 - val_loss: 8.6443 - val_accuracy: 0.0849 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 88/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7471 - accuracy: 0.8316
# Epoch 00088: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7471 - accuracy: 0.8316 - val_loss: 8.6702 - val_accuracy: 0.0873 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 89/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7622 - accuracy: 0.8281
# Epoch 00089: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7622 - accuracy: 0.8281 - val_loss: 8.7993 - val_accuracy: 0.0908 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 90/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.8356
# Epoch 00090: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7341 - accuracy: 0.8356 - val_loss: 8.9370 - val_accuracy: 0.0884 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 91/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7461 - accuracy: 0.8316
# Epoch 00091: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 0.7461 - accuracy: 0.8316 - val_loss: 8.9474 - val_accuracy: 0.0902 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 92/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7516 - accuracy: 0.8264
# Epoch 00092: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 820ms/step - loss: 0.7516 - accuracy: 0.8264 - val_loss: 8.9436 - val_accuracy: 0.0867 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 93/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7124 - accuracy: 0.8395
# Epoch 00093: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 0.7124 - accuracy: 0.8395 - val_loss: 8.8923 - val_accuracy: 0.0913 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 94/100
# 214/214 [==============================] - ETA: 0s - loss: 0.6978 - accuracy: 0.8405
# Epoch 00094: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.6978 - accuracy: 0.8405 - val_loss: 9.0719 - val_accuracy: 0.0913 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 95/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7077 - accuracy: 0.8426
# Epoch 00095: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7077 - accuracy: 0.8426 - val_loss: 9.0797 - val_accuracy: 0.0913 - lr: 3.1623e-05
# Learning rate:  0.0001
# Epoch 96/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7267 - accuracy: 0.8365
# Epoch 00096: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7267 - accuracy: 0.8365 - val_loss: 8.9895 - val_accuracy: 0.0873 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 97/100
# 214/214 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.8410
# Epoch 00097: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 0.6920 - accuracy: 0.8410 - val_loss: 9.0524 - val_accuracy: 0.0890 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 98/100
# 214/214 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.8442
# Epoch 00098: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.7046 - accuracy: 0.8442 - val_loss: 9.0751 - val_accuracy: 0.0919 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 99/100
# 214/214 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.8410
# Epoch 00099: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 818ms/step - loss: 0.6969 - accuracy: 0.8410 - val_loss: 9.1806 - val_accuracy: 0.0919 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 100/100
# 214/214 [==============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.8452
# Epoch 00100: val_accuracy did not improve from 0.12565
# 214/214 [==============================] - 175s 819ms/step - loss: 0.6890 - accuracy: 0.8452 - val_loss: 9.2209 - val_accuracy: 0.0925 - lr: 3.1623e-05

# %%
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
