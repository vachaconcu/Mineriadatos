# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import tarfile
from skimage import data
from os import remove
from skimage.color import rgb2gray
from numpy import load
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img
from sklearn.model_selection import train_test_split
from google.colab import files
from keras.layers import Conv2D, Conv2DTranspose, Input, Flatten, Dense, Lambda, Reshape,ZeroPadding2D,Activation,MaxPooling2D,Dropout
from keras.layers import BatchNormalization
from keras.models import Model
from keras.utils import plot_model
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.losses import binary_crossentropy
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SpatialDropout2D
from matplotlib import pyplot as plt
import keras
# Out:
# Using TensorFlow backend.

# %%
import os
os.chdir('/content/drive/My Drive/Minería de Datos/Train-Test 90%')

datos= load('/content/drive/My Drive/Minería de Datos/Train-Test 90%/x_test.npz') ; X_test = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Train-Test 90%/x_train.npz') ; X_train = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Train-Test 90%/y_test_s.npz') ; y_test = datos['arr_0']
datos= load('/content/drive/My Drive/Minería de Datos/Train-Test 90%/y_train_s.npz') ; y_train = datos['arr_0']

# %%
print('X_test =',X_test.shape)
print('X_train =',X_train.shape)
print('y_test =',y_test.shape)
print('y_train =',y_train.shape)
# Out:
# X_test = (1177, 200, 200, 3)
# X_train = (10584, 200, 200, 3)
# y_test = (1177, 2)
# y_train = (10584, 2)

# %%
def model(input_shape):
    # Define the input placeholder. 
    X_input = Input(input_shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(16, (3, 3),padding='same',name='Conv16')(X) 
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    
    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool_1')(X)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (3, 3),padding='same',name='Conv32')(X) 
    X = BatchNormalization(axis = 3,)(X)
    X = Dropout(0.5)(X)
    X = Activation('relu')(X)
    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool_2')(X)

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(64, (3, 3),padding='same',name='Conv64')(X) 
    X = BatchNormalization(axis = 3)(X)
    X = Dropout(0.5)(X)
    X = Activation('relu')(X)
       
    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool_3')(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dropout(0.5)(X)
    X = Dense(2, activation='sigmoid', name='final')(X)

    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='Sexo_Model')
    
    return model

# %%
Modelo = model((200,200,3))
plot_model(Modelo)

# %%
Modelo.summary()
# Out:
# Model: "Sexo_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200, 200, 3)       0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 206, 206, 3)       0
# _________________________________________________________________
# Conv16 (Conv2D)              (None, 206, 206, 16)      448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 206, 206, 16)      64
# _________________________________________________________________
# activation_1 (Activation)    (None, 206, 206, 16)      0
# _________________________________________________________________
# max_pool_1 (MaxPooling2D)    (None, 103, 103, 16)      0
# _________________________________________________________________
# Conv32 (Conv2D)              (None, 103, 103, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 103, 103, 32)      128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 103, 103, 32)      0
# _________________________________________________________________
# activation_2 (Activation)    (None, 103, 103, 32)      0
# _________________________________________________________________
# max_pool_2 (MaxPooling2D)    (None, 51, 51, 32)        0
# _________________________________________________________________
# Conv64 (Conv2D)              (None, 51, 51, 64)        18496
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 51, 51, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 51, 51, 64)        0
# _________________________________________________________________
# activation_3 (Activation)    (None, 51, 51, 64)        0
# _________________________________________________________________
# max_pool_3 (MaxPooling2D)    (None, 25, 25, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 40000)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 40000)             0
# _________________________________________________________________
# final (Dense)                (None, 2)                 80002
# =================================================================
# Total params: 104,034
# Trainable params: 103,810
# Non-trainable params: 224
# _________________________________________________________________

# %%
Modelo.compile(optimizer = "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
history= Modelo.fit(x = X_train,y = y_train,validation_data=(X_test,y_test),epochs =40 ,batch_size = 32)
# Out:
# Train on 10584 samples, validate on 1177 samples
# Epoch 1/40
# 10584/10584 [==============================] - 604s 57ms/step - loss: 0.4684 - accuracy: 0.8211 - val_loss: 0.4015 - val_accuracy: 0.8547
# Epoch 2/40
# 10584/10584 [==============================] - 613s 58ms/step - loss: 0.3296 - accuracy: 0.8594 - val_loss: 0.4273 - val_accuracy: 0.8564
# Epoch 3/40
# 10584/10584 [==============================] - 616s 58ms/step - loss: 0.2838 - accuracy: 0.8797 - val_loss: 0.4030 - val_accuracy: 0.8059
# Epoch 4/40
# 10584/10584 [==============================] - 615s 58ms/step - loss: 0.2658 - accuracy: 0.8871 - val_loss: 0.3474 - val_accuracy: 0.8849
# Epoch 5/40
# 10584/10584 [==============================] - 607s 57ms/step - loss: 0.2527 - accuracy: 0.8934 - val_loss: 0.3845 - val_accuracy: 0.8683
# Epoch 6/40
# 10584/10584 [==============================] - 597s 56ms/step - loss: 0.2370 - accuracy: 0.8990 - val_loss: 0.3484 - val_accuracy: 0.8590
# Epoch 7/40
# 10584/10584 [==============================] - 582s 55ms/step - loss: 0.2304 - accuracy: 0.9056 - val_loss: 0.3290 - val_accuracy: 0.8857
# Epoch 8/40
# 10584/10584 [==============================] - 580s 55ms/step - loss: 0.2199 - accuracy: 0.9060 - val_loss: 0.3633 - val_accuracy: 0.8764
# Epoch 9/40
# 10584/10584 [==============================] - 584s 55ms/step - loss: 0.2082 - accuracy: 0.9133 - val_loss: 0.3082 - val_accuracy: 0.8895
# Epoch 10/40
# 10584/10584 [==============================] - 605s 57ms/step - loss: 0.2040 - accuracy: 0.9126 - val_loss: 0.3186 - val_accuracy: 0.8721
# Epoch 11/40
# 10584/10584 [==============================] - 578s 55ms/step - loss: 0.2031 - accuracy: 0.9137 - val_loss: 0.2982 - val_accuracy: 0.8768
# Epoch 12/40
# 10584/10584 [==============================] - 576s 54ms/step - loss: 0.1946 - accuracy: 0.9175 - val_loss: 0.3176 - val_accuracy: 0.8883
# Epoch 13/40
# 10584/10584 [==============================] - 571s 54ms/step - loss: 0.1857 - accuracy: 0.9212 - val_loss: 0.3191 - val_accuracy: 0.8641
# Epoch 14/40
# 10584/10584 [==============================] - 575s 54ms/step - loss: 0.1807 - accuracy: 0.9261 - val_loss: 0.3215 - val_accuracy: 0.8636
# Epoch 15/40
# 10584/10584 [==============================] - 569s 54ms/step - loss: 0.1714 - accuracy: 0.9297 - val_loss: 0.3733 - val_accuracy: 0.8161
# Epoch 16/40
# 10584/10584 [==============================] - 573s 54ms/step - loss: 0.1669 - accuracy: 0.9300 - val_loss: 0.3136 - val_accuracy: 0.8789
# Epoch 17/40
# 10584/10584 [==============================] - 573s 54ms/step - loss: 0.1611 - accuracy: 0.9329 - val_loss: 0.2800 - val_accuracy: 0.8925
# Epoch 18/40
# 10584/10584 [==============================] - 598s 57ms/step - loss: 0.1558 - accuracy: 0.9333 - val_loss: 0.3153 - val_accuracy: 0.8921
# Epoch 19/40
# 10584/10584 [==============================] - 608s 57ms/step - loss: 0.1580 - accuracy: 0.9362 - val_loss: 0.2877 - val_accuracy: 0.8840
# Epoch 20/40
# 10584/10584 [==============================] - 608s 57ms/step - loss: 0.1500 - accuracy: 0.9393 - val_loss: 0.2519 - val_accuracy: 0.9006
# Epoch 21/40
# 10584/10584 [==============================] - 611s 58ms/step - loss: 0.1390 - accuracy: 0.9449 - val_loss: 0.2440 - val_accuracy: 0.9087
# Epoch 22/40
# 10584/10584 [==============================] - 601s 57ms/step - loss: 0.1453 - accuracy: 0.9402 - val_loss: 0.3110 - val_accuracy: 0.8636
# Epoch 23/40
# 10584/10584 [==============================] - 580s 55ms/step - loss: 0.1408 - accuracy: 0.9424 - val_loss: 0.2498 - val_accuracy: 0.9040
# Epoch 24/40
# 10584/10584 [==============================] - 578s 55ms/step - loss: 0.1368 - accuracy: 0.9443 - val_loss: 0.2431 - val_accuracy: 0.9002
# Epoch 25/40
# 10584/10584 [==============================] - 563s 53ms/step - loss: 0.1341 - accuracy: 0.9456 - val_loss: 0.2459 - val_accuracy: 0.9087
# Epoch 26/40
# 10584/10584 [==============================] - 563s 53ms/step - loss: 0.1306 - accuracy: 0.9475 - val_loss: 0.2477 - val_accuracy: 0.9061
# Epoch 27/40
# 10584/10584 [==============================] - 563s 53ms/step - loss: 0.1294 - accuracy: 0.9491 - val_loss: 0.2433 - val_accuracy: 0.9027
# Epoch 28/40
# 10584/10584 [==============================] - 583s 55ms/step - loss: 0.1249 - accuracy: 0.9508 - val_loss: 0.2515 - val_accuracy: 0.9074
# Epoch 29/40
# 10584/10584 [==============================] - 577s 54ms/step - loss: 0.1191 - accuracy: 0.9527 - val_loss: 0.2518 - val_accuracy: 0.8989
# Epoch 30/40
# 10584/10584 [==============================] - 575s 54ms/step - loss: 0.1172 - accuracy: 0.9528 - val_loss: 0.2517 - val_accuracy: 0.9019
# Epoch 31/40
# 10584/10584 [==============================] - 572s 54ms/step - loss: 0.1143 - accuracy: 0.9545 - val_loss: 0.2358 - val_accuracy: 0.9040
# Epoch 32/40
# 10584/10584 [==============================] - 578s 55ms/step - loss: 0.1140 - accuracy: 0.9531 - val_loss: 0.2715 - val_accuracy: 0.8798
# Epoch 33/40
# 10584/10584 [==============================] - 584s 55ms/step - loss: 0.1070 - accuracy: 0.9594 - val_loss: 0.2369 - val_accuracy: 0.9112
# Epoch 34/40
# 10584/10584 [==============================] - 588s 56ms/step - loss: 0.1105 - accuracy: 0.9576 - val_loss: 0.2557 - val_accuracy: 0.8976
# Epoch 35/40
# 10584/10584 [==============================] - 582s 55ms/step - loss: 0.1052 - accuracy: 0.9582 - val_loss: 0.2935 - val_accuracy: 0.8670
# Epoch 36/40
# 10584/10584 [==============================] - 600s 57ms/step - loss: 0.1091 - accuracy: 0.9561 - val_loss: 0.2506 - val_accuracy: 0.9019
# Epoch 37/40
# 10584/10584 [==============================] - 593s 56ms/step - loss: 0.1020 - accuracy: 0.9591 - val_loss: 0.2479 - val_accuracy: 0.9112
# Epoch 38/40
# 10584/10584 [==============================] - 602s 57ms/step - loss: 0.1002 - accuracy: 0.9601 - val_loss: 0.2462 - val_accuracy: 0.9006
# Epoch 39/40
# 10584/10584 [==============================] - 597s 56ms/step - loss: 0.1010 - accuracy: 0.9598 - val_loss: 0.3250 - val_accuracy: 0.8598
# Epoch 40/40
# 10584/10584 [==============================] - 584s 55ms/step - loss: 0.1026 - accuracy: 0.9587 - val_loss: 0.2651 - val_accuracy: 0.8840

# %%
preds = Modelo.evaluate(x = X_test,y = y_test)
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 1177/1177 [==============================] - 20s 17ms/step
#
# Loss = 0.2651312249564679
# Test Accuracy = 0.8840271830558777

# %%
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Modelo.save('/content/drive/My Drive/Minería de Datos/Train-Test 90%.modelo1_sexo.h5')

# %%
Modelo = keras.models.load_model('/content/drive/My Drive/Minería de Datos/Train-Test 90%.modelo1_sexo.h5')
